# %%
### TODO
# allow running as .py instead of just in notebook

# %%
### SET LIST OF WORKLOADS WITH EMON TO PROCESS
# you can input start and stop intervals if you want, or they will be automatically estimated
# dict keys are:
#   name - workload name and config. Is currently parsed on underscores to get name, instance count, cores per instance, core freq, uncore freq, dram freq, emon events captured
#   perf - performance / throughput of the run
#   metrics - metric xml to add to data
#   start - interval number indicating start of workload, optional
#   stop - interval number indicating stop of workload, optional
#   emon-dir - directory where emon.log exists; it is expected that emonv.log and emonM.log exist in the same dir or parent dir of emon-dir

emon_100ms_default = [
    {'name': 'qanet-infer_56i_1cpi_defcf_defuf_2666df_default', 'perf': '412.45', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_defaultcf_defaultuf_2666df_configEmon100ms/aibench-20190305214342956620/dummy-0-57fc5978f-5qn2r/emon-05032019063344'},
    {'name': 'qanet-infer_56i_1cpi_2.1cf_2.4uf_2666df_default', 'perf': '413.16', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_2.1cf_2.4uf_2666df_configEmon100ms/aibench-20190306012816341326/dummy-0-5595dbfd79-bhgzw/emon-05032019173024'},
    {'name': 'qanet-infer_56i_1cpi_1.8cf_2.4uf_2666df_default', 'perf': '371.47', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_1.8cf_2.4uf_2666df_configEmon100ms/aibench-20190306060310412827/dummy-0-7f9d85c9bf-cq2n6/emon-05032019220837'},
    {'name': 'qanet-infer_56i_1cpi_1.5cf_2.4uf_2666df_default', 'perf': '320.54', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_1.5cf_2.4uf_2666df_configEmon100ms/aibench-20190305223111969559/dummy-0-55f48c5bb7-pnnqf/emon-04032019064255'},
    {'name': 'qanet-infer_56i_1cpi_2.1cf_2.4uf_2400df_default', 'perf': '412.15', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_2.1cf_2.4uf_2400df_configEmon100ms/aibench-20190305232158129939/dummy-0-6c5f8fcf4b-gt8p8/emon-05032019152922'},
    {'name': 'qanet-infer_56i_1cpi_2.1cf_2.4uf_2133df_default', 'perf': '401.62', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_2.1cf_2.4uf_2133df_configEmon100ms/aibench-20190305235222106865/dummy-0-79c48b7768-c82mk/emon-05032019161346'},
    {'name': 'qanet-infer_28i_1cpi_2.1cf_2.4uf_2666df_default', 'perf': '198.40', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/28instances_1cores-per-inst_2.1cf_2.4uf_2666df_configEmon100ms/aibench-20190306020219921755/dummy-0-5595dbfd79-zxg7r/emon-05032019180353'},
    {'name': 'qanet-infer_14i_1cpi_2.1cf_2.4uf_2666df_default', 'perf': '112.31', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/14instances_1cores-per-inst_2.1cf_2.4uf_2666df_configEmon100ms/aibench-20190306043738333144/dummy-0-5595dbfd79-jvr7v/emon-05032019203901'},
    #
    {'name': 'deepvoice3_56i_1cpi_defcf_defuf_2666df_default', 'perf': '486.26', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/_cfDefault_ufDefault_df2666_Emon100ms-instances56_cores-per-inst1/aibench-20190228191944190361/dummy-0-55f48c5bb7-5sf7g/emon-28022019112202'},
    {'name': 'deepvoice3_56i_1cpi_2.1cf_2.4uf_2666df_default', 'perf': '408.13', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/56instances_1cores-per-inst_2.1cf_2.4uf_2666df_configEmon100ms/aibench-20190306002535795977/dummy-0-5595dbfd79-47kdl/emon-05032019162743'},
    {'name': 'deepvoice3_56i_1cpi_1.8cf_2.4uf_2666df_default', 'perf': '349.78', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/56instances_1cores-per-inst_1.8cf_2.4uf_2666df_configEmon100ms/aibench-20190305214619866265/dummy-0-7f9d85c9bf-xtd97/emon-05032019135712'},
    {'name': 'deepvoice3_56i_1cpi_1.5cf_2.4uf_2666df_default', 'perf': '300.90', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/56instances_1cores-per-inst_1.5cf_2.4uf_2666df_configEmon100ms/aibench-20190305210105076122/dummy-0-55f48c5bb7-zgw6m/emon-05032019133801'},
    {'name': 'deepvoice3_56i_1cpi_2.1cf_2.4uf_2400df_default', 'perf': '406.37', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/56instances_1cores-per-inst_2.1cf_2.4uf_2400df_configEmon100ms/aibench-20190306234523412142/dummy-0-6c5f8fcf4b-x7jkh/emon-06032019154732'},
    {'name': 'deepvoice3_56i_1cpi_2.1cf_2.4uf_2133df_default', 'perf': '412.53', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/56instances_1cores-per-inst_2.1cf_2.4uf_2133df_configEmon100ms/aibench-20190306184846648342/dummy-0-79c48b7768-p6f4f/emon-06032019105153'},
    {'name': 'deepvoice3_28i_1cpi_2.1cf_2.4uf_2666df_default', 'perf': '207.75', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/28instances_1cores-per-inst_2.1cf_2.4uf_2666df_configEmon100ms/aibench-20190306004314065865/dummy-0-5595dbfd79-pctf7/emon-05032019164540'},
    {'name': 'deepvoice3_14i_1cpi_2.1cf_2.4uf_2666df_default', 'perf': '105.41', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/14instances_1cores-per-inst_2.1cf_2.4uf_2666df_configEmon100ms/aibench-20190306010054548175/dummy-0-5595dbfd79-ct4d8/emon-05032019170226'},
    #
    {'name': 'widendeep_14i_4cpi_defcf_defuf_2666df_default', 'perf': '1183649.23', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/14instances_4cores-per-inst_defaultcf_defaultuf_2666df_configEmon100ms/aibench-20190307214546696500/dummy-0-6957f575c9-jpwj6/emon-07032019134818'},
    {'name': 'widendeep_14i_4cpi_2.1cf_2.4uf_2666df_default', 'perf': '1194997.47', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/14instances_4cores-per-inst_2.1cf_2.4uf_2666df_configEmon100ms/aibench-20190307192501844387/dummy-0-7d968c89fc-whx7k/emon-07032019112612'},
    {'name': 'widendeep_14i_4cpi_1.8cf_2.4uf_2666df_default', 'perf': '1158440.75', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/14instances_4cores-per-inst_1.8cf_2.4uf_2666df_configEmon100ms/aibench-20190307011108422077/dummy-0-984c6fcff-zjtdx/emon-06032019171220'},
    {'name': 'widendeep_14i_4cpi_1.5cf_2.4uf_2666df_default', 'perf': '1014214.89', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/14instances_4cores-per-inst_1.5cf_2.4uf_2666df_configEmon100ms/aibench-20190307184916244047/dummy-0-c88d9764f-chdqz/emon-07032019105030'},
    {'name': 'widendeep_14i_4cpi_2.1cf_2.4uf_2400df_default', 'perf': '1206555.79', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/14instances_4cores-per-inst_2.1cf_2.4uf_2400df_configEmon100ms/aibench-20190307173446964455/dummy-0-f9c759964-2wh7p/emon-07032019093558'},
    {'name': 'widendeep_14i_4cpi_2.1cf_2.4uf_2133df_default', 'perf': '1240899.27', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/14instances_4cores-per-inst_2.1cf_2.4uf_2133df_configEmon100ms/aibench-20190307180208485443/dummy-0-6d86779946-9gmd7/emon-07032019100319'},
    {'name': 'widendeep_7i_4cpi_2.1cf_2.4uf_2666df_default',  'perf': '605536.190', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/7instances_4cores-per-inst_2.1cf_2.4uf_2666df_configEmon100ms/aibench-20190307195108418436/dummy-0-7d968c89fc-9l8wz/emon-07032019115210'},
    {'name': 'widendeep_3i_4cpi_2.1cf_2.4uf_2666df_default',  'perf': '290402.900', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/3instances_4cores-per-inst_2.1cf_2.4uf_2666df_configEmon100ms/aibench-20190307202117715866/dummy-0-7d968c89fc-pwrxj/emon-07032019122217'},
]

emon_10ms_flops = [
    {'name': 'qanet-infer_56i_1cpi_defcf_defuf_2666df_flops', 'perf': '400.40', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_defaultcf_defaultuf_2666df_configEmon10msFlops/aibench-20190305221107203265/dummy-0-57fc5978f-kl6hb/emon-07032019021755'},
    {'name': 'qanet-infer_56i_1cpi_2.1cf_2.4uf_2666df_flops', 'perf': '403.56', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_2.1cf_2.4uf_2666df_configEmon10msFlops/aibench-20190306014240666430/dummy-0-5595dbfd79-j9hpm/emon-05032019174451'},
    {'name': 'qanet-infer_56i_1cpi_1.8cf_2.4uf_2666df_flops', 'perf': '370.20', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_1.8cf_2.4uf_2666df_configEmon10msFlops/aibench-20190327183958175504/dummy-0-78c4f47b5-c75cd/emon-27032019115113'},
    {'name': 'qanet-infer_56i_1cpi_1.5cf_2.4uf_2666df_flops', 'perf': '315.38', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_1.5cf_2.4uf_2666df_configEmon10msFlops/aibench-20190305224653776747/dummy-0-55f48c5bb7-6gqlc/emon-26032019211714'},
    {'name': 'qanet-infer_56i_1cpi_2.1cf_2.4uf_2400df_flops', 'perf': '394.03', 'metrics': 'skx-2s-flops-only.xml', 'start': 2000, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_2.1cf_2.4uf_2400df_configEmon10msFlops/aibench-20190305233547283305/dummy-0-6c5f8fcf4b-2gpzt/emon-05032019144531'},
    {'name': 'qanet-infer_56i_1cpi_2.1cf_2.4uf_2133df_flops', 'perf': '406.51', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_2.1cf_2.4uf_2133df_configEmon10msFlops/aibench-20190306000553682228/dummy-0-79c48b7768-h27f8/emon-05032019115749'},
    {'name': 'qanet-infer_28i_1cpi_2.1cf_2.4uf_2666df_flops', 'perf': '194.06', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/28instances_1cores-per-inst_2.1cf_2.4uf_2666df_configEmon10msFlops/aibench-20190306021602015895/dummy-0-5595dbfd79-drwwk/emon-05032019181736'},
    {'name': 'qanet-infer_14i_1cpi_2.1cf_2.4uf_2666df_flops', 'perf': '110.57', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/14instances_1cores-per-inst_2.1cf_2.4uf_2666df_configEmon10msFlops/aibench-20190306053614629595/dummy-0-5595dbfd79-cs7gk/emon-05032019213651'},
    #
    {'name': 'deepvoice3_56i_1cpi_defcf_defuf_2666df_flops', 'perf': '489.30', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/_cfDefault_ufDefault_df2666_Emon10msFlops-instances56_cores-per-inst1/aibench-20190228215345815736/dummy-0-55f48c5bb7-6wn4v/emon-28022019135615'},
    {'name': 'deepvoice3_56i_1cpi_2.1cf_2.4uf_2666df_flops', 'perf': '403.95', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/56instances_1cores-per-inst_2.1cf_2.4uf_2666df_configEmon10msFlops/aibench-20190305225208761626/dummy-0-5595dbfd79-p6g4k/emon-05032019145418'},
    {'name': 'deepvoice3_56i_1cpi_1.8cf_2.4uf_2666df_flops', 'perf': '360.42', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/56instances_1cores-per-inst_1.8cf_2.4uf_2666df_configEmon10msFlops/aibench-20190305220655979424/dummy-0-7f9d85c9bf-96pz5/emon-05032019083021'},
    {'name': 'deepvoice3_56i_1cpi_1.5cf_2.4uf_2666df_flops', 'perf': '299.21', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/56instances_1cores-per-inst_1.5cf_2.4uf_2666df_configEmon10msFlops/aibench-20190305202335110957/dummy-0-55f48c5bb7-hwhg5/emon-05032019122420'},
    {'name': 'deepvoice3_56i_1cpi_2.1cf_2.4uf_2400df_flops', 'perf': '404.37', 'metrics': 'skx-2s-flops-only.xml', 'start': 6000, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/56instances_1cores-per-inst_2.1cf_2.4uf_2400df_configEmon10msFlops/aibench-20190306175415637836/dummy-0-6c5f8fcf4b-888mz/emon-06032019095621'},
    {'name': 'deepvoice3_56i_1cpi_2.1cf_2.4uf_2133df_flops', 'perf': '398.57', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/56instances_1cores-per-inst_2.1cf_2.4uf_2133df_configEmon10msFlops/aibench-20190306183014805328/dummy-0-79c48b7768-f8995/emon-06032019103222'},
    {'name': 'deepvoice3_28i_1cpi_2.1cf_2.4uf_2666df_flops', 'perf': '207.41', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/28instances_1cores-per-inst_2.1cf_2.4uf_2666df_configEmon10msFlops/aibench-20190305231344506031/dummy-0-5595dbfd79-bx99g/emon-05032019151524'},
    {'name': 'deepvoice3_14i_1cpi_2.1cf_2.4uf_2666df_flops', 'perf': '107.09', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Text_to_Speech_deepvoice3/SF1/14instances_1cores-per-inst_2.1cf_2.4uf_2666df_configEmon10msFlops/aibench-20190305233038128751/dummy-0-5595dbfd79-jpmg4/emon-05032019153226'},
    #
    {'name': 'widendeep_14i_4cpi_defcf_defuf_2666df_flops', 'perf': '1187268.15', 'metrics': 'skx-2s-flops-only.xml', 'start': None,  'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/14instances_4cores-per-inst_defaultcf_defaultuf_2666df_configEmon10msFlops/aibench-20190307215916100277/dummy-0-6957f575c9-9mpmr/emon-07032019140033'},
    {'name': 'widendeep_14i_4cpi_2.1cf_2.4uf_2666df_flops', 'perf': '1244037.25', 'metrics': 'skx-2s-flops-only.xml', 'start': 28000, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/14instances_4cores-per-inst_2.1cf_2.4uf_2666df_configEmon10msFlops/aibench-20190307193746689733/dummy-0-7d968c89fc-tvlnj/emon-07032019113858'},
    {'name': 'widendeep_14i_4cpi_1.8cf_2.4uf_2666df_flops', 'perf': '1151220.36', 'metrics': 'skx-2s-flops-only.xml', 'start': None,  'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/14instances_4cores-per-inst_1.8cf_2.4uf_2666df_configEmon10msFlops/aibench-20190307012625584626/dummy-0-984c6fcff-jtmgv/emon-06032019172737'},
    {'name': 'widendeep_14i_4cpi_1.5cf_2.4uf_2666df_flops', 'perf': '991500.700', 'metrics': 'skx-2s-flops-only.xml', 'start': None,  'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/14instances_4cores-per-inst_1.5cf_2.4uf_2666df_configEmon10msFlops/aibench-20190307190211132957/dummy-0-c88d9764f-dwnq2/emon-07032019110323'},
    {'name': 'widendeep_14i_4cpi_2.1cf_2.4uf_2400df_flops', 'perf': '1199668.63', 'metrics': 'skx-2s-flops-only.xml', 'start': None,  'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/14instances_4cores-per-inst_2.1cf_2.4uf_2400df_configEmon10msFlops/aibench-20190307174806012803/dummy-0-f9c759964-g6qwg/emon-07032019094916'},
    {'name': 'widendeep_14i_4cpi_2.1cf_2.4uf_2133df_flops', 'perf': '1160910.62', 'metrics': 'skx-2s-flops-only.xml', 'start': None,  'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/14instances_4cores-per-inst_2.1cf_2.4uf_2133df_configEmon10msFlops/aibench-20190307182212286073/dummy-0-6d86779946-rthpp/emon-07032019102323'},
    {'name': 'widendeep_7i_4cpi_2.1cf_2.4uf_2666df_flops',  'perf': '586872.490', 'metrics': 'skx-2s-flops-only.xml', 'start': None,  'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/7instances_4cores-per-inst_2.1cf_2.4uf_2666df_configEmon10msFlops/aibench-20190307200427086779/dummy-0-7d968c89fc-t6wmb/emon-07032019120530'},
    {'name': 'widendeep_3i_4cpi_2.1cf_2.4uf_2666df_flops',  'perf': '298512.050', 'metrics': 'skx-2s-flops-only.xml', 'start': None,  'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/MXNET/wide-n-deep/emon_data_rerun/3instances_4cores-per-inst_2.1cf_2.4uf_2666df_configEmon10msFlops/aibench-20190307211231911212/dummy-0-7d968c89fc-prqdj/emon-07032019131331'},
]

emon_10ms_flops_avx2 = [{'name': 'qanet-infer_56i_1cpi_defcf_defuf_2666df_flops-avx2', 'perf': '460.22', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON-AVX2/56instances_1cores-per-inst_defaultcf_defaultuf_defaultdf_configEmon10msFlops/aibench-20190408221802703022/dummy-0-86f6688d4b-sdp7s/emon-08042019152612'}]
flops_test = [{'name': 'qanet-infer_56i_1cpi_defcf_defuf_2666df_flops', 'perf': '400.40', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_defaultcf_defaultuf_2666df_configEmon10msFlops/aibench-20190305221107203265/dummy-0-57fc5978f-kl6hb/emon-07032019021755'}]
default_test = [{'name': 'qanet-infer_56i_1cpi_defcf_defuf_2666df_default', 'perf': '412.45', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/QANet/standalone_qanet_inference/EMON/56instances_1cores-per-inst_defaultcf_defaultuf_2666df_configEmon100ms/aibench-20190305214342956620/dummy-0-57fc5978f-5qn2r/emon-05032019063344'}]
srgans = [{'name': 'srgans', 'perf': None, 'start': None, 'stop': None, 'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/performance/pods/perf-nineteen-0-6fbf77596d-ththg/emon-26032019111344'}]
resnet50 = [{'name': 'resnet50', 'perf': None, 'start': None, 'stop': None, 'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/cnn/aibench-20190328185652939458/dummy-0-696bb4ff75-f7skf/emon-28032019115844'}]
nasar_flops = [{'name': 'srgans_14i_4cpi_defcf_defuf_2666df_flops', 'perf': '4.00', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/performance/pods/perf-nineteen-0-6fbf77596d-ththg/emon-10msFlops-4_14_localsave'}]
nasar_default = [{'name': 'srgans_14i_4cpi_defcf_defuf_2666df_default', 'perf': '4.10', 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/performance/pods/perf-nineteen-0-6fbf77596d-ththg/emon-100ms-4_14_localsave'}]
prachi_flops = [{'name': '3dunet_14i_4cpi_defcf_defuf_2666df_flops', 'perf': '3.14', 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/unet3d-inference-e1/aibench-20190411103016966293/dummy-0-f4cbddc68-fjmjd/emon-11042019103049'}]

face_rec_100ms_default = [{'name': 'face-rec_56i_1cpi_2.1cf_2.4uf_2666df_default', 'perf': None, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Face_Recognition/tensorflow_1.12/e2e_core_scaling/SF1/EMON-100ms-aibench-20181211020203139652/dummy-one-0-6545d6c8f4-dfmsg/emon-10122018184240'}]
face_rec_10ms_default = [
    {'name': 'face-rec-infer_56i_1cpi_2.1cf_2.4uf_2666df_default', 'perf': None, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Face_Recognition/tensorflow_1.12/e2e_core_scaling/SF1/EMON-10ms-aibench-20181211075515147320/dummy-one-0-6545d6c8f4-vzj2k-inference-two/emon-11122018003513'},
    {'name': 'face-rec-detect_56i_1cpi_2.1cf_2.4uf_2666df_default', 'perf': None, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Face_Recognition/tensorflow_1.12/e2e_core_scaling/SF1/EMON-10ms-aibench-20181211075515147320/dummy-three-0-6bc6744674-rj266-decode-detect/emon-11122018003523'},
    {'name': 'face-rec-broker_1i_56cpi_2.1cf_2.4uf_2666df_default', 'perf': None, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Face_Recognition/tensorflow_1.12/e2e_core_scaling/SF1/EMON-10ms-aibench-20181211075515147320/dummy-two-0-78b79dd85c-q77rx-broker/emon-11122018003501'},
]

lrcn_10ms_flops = [{'name': 'lrcn_28i_2cpi_2.1cf_2.4uf_2666df_flops', 'perf': None, 'metrics': 'skx-2s-flops-only.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/lrcn/lrcn-activity-recognition-batch-inference/core-scaling/_cf2100.0_uf2400.0_df2666.0-instances28_cores-per-inst2-emon'}]
lrcn_100ms_seabass = [{'name': 'lrcn_14i_4cpi_2.5cf_2.4uf_2666df_default', 'perf': None, 'metrics': 'skx-2s', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/lrcn/lrcn-activity-recognition-batch-inference/seabass/intel_caffe/SKX/lrcn_activity_recognition_poc-facenet-2018-07-05-18-54-33-4core-14inst-default10ms/results/lrcn_activity_recognition/seabass_result/lrcn_activity_recognition/experiments/lrcn_activity_recognition/lrcn_activity_recognition-poc-facenet-2018-07-05-18-54-33/run_1/instruments/fmwpaxeon79'}]

kafka_broker = [
    {'name': 'kafka-broker1-1x_1i_56cpi_defcf_defuf_2666df_default', 'perf': None, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/users/drichins/Data/FR-Emulation/PROFILE-emon/BROKER_CORES-56/BROKERS-3/STORAGE_MEDIUM-ssd/STORAGE_DEVICES-1/PRODUCERS-15/CONSUMERS-22/ITEMS_PER_ELEMENT-1/PRODUCER_BATCH_SIZE-1024/PRODUCER_LINGER_MS-0/CONSUMER_FMB-40000/CONSUMER_FMWM-10/ITEM_SIZE-37331/ELEMENT_COUNT-18000/SPEED-1.0/emon/perf-daniel-seventeen-0-57d5cdfb6b-ps7hc/emon-01052019222632'},
    {'name': 'kafka-broker2-1x_1i_56cpi_defcf_defuf_2666df_default', 'perf': None, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/users/drichins/Data/FR-Emulation/PROFILE-emon/BROKER_CORES-56/BROKERS-3/STORAGE_MEDIUM-ssd/STORAGE_DEVICES-1/PRODUCERS-15/CONSUMERS-22/ITEMS_PER_ELEMENT-1/PRODUCER_BATCH_SIZE-1024/PRODUCER_LINGER_MS-0/CONSUMER_FMB-40000/CONSUMER_FMWM-10/ITEM_SIZE-37331/ELEMENT_COUNT-18000/SPEED-1.0/emon/perf-daniel-fifty-five-0-5cb5cbdf64-qrk2h/emon-01052019222632'},
    {'name': 'kafka-broker3-1x_1i_56cpi_defcf_defuf_2666df_default', 'perf': None, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/users/drichins/Data/FR-Emulation/PROFILE-emon/BROKER_CORES-56/BROKERS-3/STORAGE_MEDIUM-ssd/STORAGE_DEVICES-1/PRODUCERS-15/CONSUMERS-22/ITEMS_PER_ELEMENT-1/PRODUCER_BATCH_SIZE-1024/PRODUCER_LINGER_MS-0/CONSUMER_FMB-40000/CONSUMER_FMWM-10/ITEM_SIZE-37331/ELEMENT_COUNT-18000/SPEED-1.0/emon/perf-daniel-ninety-eight-0-786c599869-rwhk7/emon-01052019222632'},
    {'name': 'kafka-broker1-6x_1i_56cpi_defcf_defuf_2666df_default', 'perf': None, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/users/drichins/Data/FR-Emulation/PROFILE-emon/BROKER_CORES-56/BROKERS-3/STORAGE_MEDIUM-ssd/STORAGE_DEVICES-1/PRODUCERS-15/CONSUMERS-22/ITEMS_PER_ELEMENT-1/PRODUCER_BATCH_SIZE-1024/PRODUCER_LINGER_MS-0/CONSUMER_FMB-40000/CONSUMER_FMWM-10/ITEM_SIZE-37331/ELEMENT_COUNT-18000/SPEED-6.0/emon/perf-daniel-seventeen-0-57d5cdfb6b-bshcw/emon-02052019085035'},
    {'name': 'kafka-broker2-6x_1i_56cpi_defcf_defuf_2666df_default', 'perf': None, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/users/drichins/Data/FR-Emulation/PROFILE-emon/BROKER_CORES-56/BROKERS-3/STORAGE_MEDIUM-ssd/STORAGE_DEVICES-1/PRODUCERS-15/CONSUMERS-22/ITEMS_PER_ELEMENT-1/PRODUCER_BATCH_SIZE-1024/PRODUCER_LINGER_MS-0/CONSUMER_FMB-40000/CONSUMER_FMWM-10/ITEM_SIZE-37331/ELEMENT_COUNT-18000/SPEED-6.0/emon/perf-daniel-fifty-five-0-5cb5cbdf64-lqqdh/emon-02052019085034'},
    {'name': 'kafka-broker3-6x_1i_56cpi_defcf_defuf_2666df_default', 'perf': None, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'emon_dir': '/mnt/san03RAID1/users/drichins/Data/FR-Emulation/PROFILE-emon/BROKER_CORES-56/BROKERS-3/STORAGE_MEDIUM-ssd/STORAGE_DEVICES-1/PRODUCERS-15/CONSUMERS-22/ITEMS_PER_ELEMENT-1/PRODUCER_BATCH_SIZE-1024/PRODUCER_LINGER_MS-0/CONSUMER_FMB-40000/CONSUMER_FMWM-10/ITEM_SIZE-37331/ELEMENT_COUNT-18000/SPEED-6.0/emon/perf-daniel-ninety-eight-0-786c599869-w7q5g/emon-02052019085035'},
]


aibench_collection_5_10 = [{
     'type': 'aibench',
     'search_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/AIBench_1.7_auto_pilot_collections',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/combined',
     'manual_start_stop': {
         'wide-n-deep-sf1_14i_4cpi_1.6cf_2.4uf_2666df_configEmon100ms': {'start': 3000, 'stop': None},
         'wide-n-deep-sf1_14i_4cpi_1.3cf_2.4uf_2666df_configEmon100ms': {'start': 3300, 'stop': None},
         'throwaway-face-decode-detection-sf1_56i_1cpi_1.9cf_2.4uf_2133df_configEmon100ms': {'start': 750, 'stop': 3600},
         'gnmt-standalone-inference-sf1_14i_2cpi_1.9cf_2.4uf_2666df_configEmon100ms': {'start': None, 'stop': 8100},
         'mzdeepspeech-inference-sf1_56i_1cpi_1.9cf_2.4uf_2666df_configEmon100ms': {'start': 870, 'stop': 10000},
         'text-to-speech-inference-sf1_56i_1cpi_1.3cf_2.4uf_2666df_configEmon100ms': {'start': 600, 'stop': 9600},
         'standalone-rcnn-inference-sf1_56i_1cpi_1.3cf_2.4uf_2666df_configEmon100ms': {'start': 1500, 'stop': 34200},
         'transformer-nmt-standalone-inference-sf1_56i_1cpi_1.9cf_2.4uf_2400df_configEmon100ms': {'start': None, 'stop': 33300},
         'qanet-standalone-inference-sf1_56i_1cpi_1.6cf_2.4uf_2666df_configEmon10msFlops': {'start': None, 'stop': 20000},
         'mzdeepspeech-inference-sf1_14i_1cpi_1.9cf_2.4uf_2666df_configEmon10msFlops': {'start': None, 'stop': 74000},
         'wide-n-deep-sf1_14i_4cpi_1.9cf_2.4uf_2133df_configEmon10msFlops': {'start': 28000, 'stop': None},
         'standalone-face-inference-sf1_28i_1cpi_1.9cf_2.4uf_2666df_configEmon10msFlops': {'start': None, 'stop': 40000},
         'wide-n-deep-sf1_14i_4cpi_1.6cf_2.4uf_2666df_configEmon10msFlops': {'start': 30000, 'stop': None},
         'wide-n-deep-sf1_14i_4cpi_1.3cf_2.4uf_2666df_configEmon10msFlops': {'start': 32000, 'stop': None},
         'mzdeepspeech-inference-sf1_28i_1cpi_1.9cf_2.4uf_2666df_configEmon10msFlops': {'start': None, 'stop': 84000},
         'standalone-face-inference-sf1_56i_1cpi_1.3cf_2.4uf_2666df_configEmon10msFlops': {'start': None, 'stop': 50000},
         'standalone-face-inference-sf1_56i_1cpi_1.9cf_2.4uf_2400df_configEmon10msFlops': {'start': None, 'stop': 40000},
         'text-to-speech-inference-sf1_56i_1cpi_1.9cf_2.4uf_2133df_configEmon10msFlops': {'start': None, 'stop': 64000},
         'standalone-rcnn-inference-sf1_28i_1cpi_1.9cf_2.4uf_2666df_configEmon10msFlops': {'start': None, 'stop': 244000},
         'standalone-rcnn-inference-sf1_56i_1cpi_1.9cf_2.4uf_2666df_configEmon10msFlops': {'start': 16000, 'stop': 254000},
         'standalone-rcnn-inference-sf1_56i_1cpi_1.9cf_2.4uf_2133df_configEmon10msFlops': {'start': 15000, 'stop': 262000},
         'transformer-nmt-standalone-inference-sf1_56i_1cpi_1.6cf_2.4uf_2666df_configEmon10msFlops': {'start': None, 'stop': 340000},
         'transformer-nmt-standalone-inference-sf1_56i_1cpi_1.9cf_2.4uf_2666df_configEmon10msFlops': {'start': 16000, 'stop': 320000},
         'transformer-nmt-standalone-inference-sf1_56i_1cpi_1.9cf_2.4uf_2400df_configEmon10msFlops': {'start': None, 'stop': 320000},
         'transformer-nmt-standalone-inference-sf1_56i_1cpi_1.9cf_2.4uf_2133df_configEmon10msFlops': {'start': None, 'stop': 330000},
         'transformer-nmt-standalone-inference-sf1_56i_1cpi_1.3cf_2.4uf_2666df_configEmon10msFlops': {'start': None, 'stop': 390000},
         'srgan-inference-sf1_14i_4cpi_1.9cf_2.4uf_2666df_configEmon10msFlops': {'start': None, 'stop': 96800},
         'unet3d-inference-sf1_56i_1cpi_1.3cf_2.4uf_2666df_configEmon100ms': {'start': 0, 'stop': 37000},
     }
}]
    
cwr = [{
    'type': 'edp',
    'search_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/cwr',
    'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/combined'
}]
    
broker = [{'name': 'kafka-broker_1i_56cpi_defcf_defuf_2666df_default', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/face-rec', 'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Face_Recognition/tensorflow_1.12/e2e_core_scaling/SF1/EMON-100ms-aibench-20181211020203139652/dummy-two-0-broker-78b79dd85c-fdslh/emon-10122018184229'}]

aibench_collection_lrcn = [{
     'type': 'aibench',
     'search_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/data_collection_2019-06-04T12:17:16-0700',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/lrcn_memory',
     'manual_start_stop': {}
}]
        
kafka_emulator_collection = [{
     'type': 'kafka-emulator',
     'search_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/kafka-benchmark/',
     'summary_file': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/kafka-benchmark/kafka-summary.csv',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/kafka_emulation',
     'agg_secs': 3.0,
     'manual_start_stop': {}
}]   
    

gnmt_numa = [
    {'name': 'gnmt_14i_2cpi_1.9cf_2.4uf_2666df_default_localmem',  'perf': 187.004, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/gnmt_numa', 'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/gnmt-standalone-inference-sf1/aibench-20190627114552943423/nmt-inference-configemon100ms-0-5cd59575cb-h2d7t/perf-fmx005-0-5c75bc97b4-7jk47/emon-27062019114628'},
    {'name': 'gnmt_14i_2cpi_1.9cf_2.4uf_2666df_default_remotemem', 'perf': 62.2752, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/gnmt_numa', 'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/gnmt-standalone-inference-sf1/aibench-20190627120642946931/nmt-inference-configemon100ms-0-5cd59575cb-r76bw/perf-fmx005-0-5c75bc97b4-7jk47/emon-27062019120713'},
    {'name': 'gnmt_1i_28cpi_1.9cf_2.4uf_2666df_default_localmem',  'perf': 99.1742, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/gnmt_numa', 'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/gnmt-standalone-inference-sf1/aibench-20190627133940891877/nmt-inference-configemon100ms-0-5cd59575cb-wgn2c/perf-fmx005-0-5c75bc97b4-7jk47/emon-27062019133957'},
    {'name': 'gnmt_1i_28cpi_1.9cf_2.4uf_2666df_default_remotemem', 'perf': 48.6245, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/gnmt_numa', 'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/gnmt-standalone-inference-sf1/aibench-20190627131956640239/nmt-inference-configemon100ms-0-5cd59575cb-gwxhx/perf-fmx005-0-5c75bc97b4-7jk47/emon-27062019132012'},
    {'name': 'gnmt_1i_2cpi_1.9cf_2.4uf_2666df_default_localmem',   'perf': 34.3421, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/gnmt_numa', 'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/gnmt-standalone-inference-sf1/aibench-20190628135047886729/nmt-inference-configemon100ms-0-5cd59575cb-kdt8n/perf-fmx005-0-5c75bc97b4-7jk47/emon-28062019135104'},
    {'name': 'gnmt_1i_2cpi_1.9cf_2.4uf_2666df_default_remotemem',  'perf': 24.8093, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml', 'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/gnmt_numa', 'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/gnmt-standalone-inference-sf1/aibench-20190628140425255409/nmt-inference-configemon100ms-0-5cd59575cb-xfl87/perf-fmx005-0-5c75bc97b4-7jk47/emon-28062019140441'},
]

faas = [
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_1_12_05_20__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_1_12_05_20__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_1_12_05_32__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_1_12_05_32__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_1_12_05_45__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_1_12_05_45__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_112_12_08_50__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_112_12_08_50__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_112_12_09_09__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_112_12_09_09__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_112_12_09_30__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_112_12_09_30__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_16_12_06_36__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_16_12_06_36__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_16_12_06_49__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_16_12_06_49__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_16_12_07_02__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_16_12_07_02__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_168_12_09_47__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_168_12_09_47__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_168_12_10_05__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_168_12_10_05__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_168_12_10_25__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_168_12_10_25__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_32_12_07_15__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_32_12_07_15__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_32_12_07_30__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_32_12_07_30__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_32_12_07_46__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_32_12_07_46__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_56_12_07_59__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_56_12_07_59__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_56_12_08_17__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_56_12_08_17__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_56_12_08_37__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_56_12_08_37__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_8_12_05_58__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_8_12_05_58__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_8_12_06_10__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_8_12_06_10__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_8_12_06_23__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_8_12_06_23__05_Jul_2019FNS'},
]

proxy_test = [
    {'name': 'proxy_1i_56cpi_defcf_defuf_2666df_proxy', 'perf': None, 'agg_secs': 0.04, 'metrics': 'skx-2s-proxy-only.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/proxy_test',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/test'},
]

example_workloads = [
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_1_12_05_20__05_Jul_2019FNS','perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_1_12_05_20__05_Jul_2019FNS'},
    {'name': 'faas_1i_56cpi_defcf_defuf_2666df_default_openfaas-nmt-ofwatchdog_1_12_05_32__05_Jul_2019FNS', 'perf': None, 'agg_secs': 3.0, 'metrics': 'skx-2s.xml',
     'start': None, 'stop': None, 'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/faas',
     'emon_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/faas/openfaas-nmt-ofwatchdog_1_12_05_32__05_Jul_2019FNS'},
]

aibt_aibench_clx = [
    {'name': 'inception-v4-imagenet-float32_56i_1cpi_defcf_defuf_2666df_default','perf': None,
     'agg_secs': 3.5, 'start': 105, 'stop': 455, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190913-123321-inception_v4_imagenet_float32'},
    {'name': 'inception-v4-imagenet-int8_56i_1cpi_defcf_defuf_2666df_default','perf': None,
     'agg_secs': 3.5, 'start': 35, 'stop': 175, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190913-123519-inception_v4_imagenet_int8'},
    {'name': 'fasterrcnn-resnet-50-v1-coco-float32_56i_1cpi_defcf_defuf_2666df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190913-123637-fasterrcnn_resnet_50_v1_coco_float32'},
    {'name': 'inception-resnet-v2-imagenet-float32_56i_1cpi_defcf_defuf_2666df_default','perf': None,
     'agg_secs': 3.5, 'start': 70, 'stop': 210, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190913-132905-inception_resnet_v2_imagenet_float32'},
    {'name': 'rfcn-resnet-101-coco-int8_56i_1cpi_defcf_defuf_2666df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190913-133038-rfcn_resnet_101_coco_int8'},
    {'name': 'inception-resnet-v2-imagenet-int8_56i_1cpi_defcf_defuf_2666df_default','perf': None,
     'agg_secs': 3.5, 'start': 35, 'stop': 140, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190913-134033-inception_resnet_v2_imagenet_int8'},
    {'name': 'fasterrcnn-resnet-50-v1-coco-int8_56i_1cpi_defcf_defuf_2666df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190913-134154-fasterrcnn_resnet_50_v1_coco_int8'},
    {'name': 'rfcn-resnet-101-coco-float32_56i_1cpi_defcf_defuf_2666df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190913-150751-rfcn_resnet_101_coco_float32'},
    
    {'name': 'transformer-nmt-standalone-inference-sf1_56i_1cpi_defcf_defuf_2666df_default','perf': 178.95,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt',
     'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Rome_SKX_CLX/CLX8280M/transformer-nmt-standalone-inference-sf1/aibench-20190913115822853664/dummy-0-7db6b86867-hbzvh/perf-0-56ccbc59d8-rx6ds/emon-13092019120347'},
    {'name': 'gnmt-standalone-inference-sf1_28i_2cpi_defcf_defuf_2666df_default','perf': 323.83,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt',
     'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Rome_SKX_CLX/CLX8280M/gnmt-standalone-inference-sf1/aibench-20190913112107731861/dummy-0-5bc55db76f-5kkxw/perf-0-696cb55d8b-jbxm4/emon-13092019112650'},
    {'name': 'qanet-standalone-inference-sf1_56i_1cpi_defcf_defuf_2666df_default','perf': 455.97,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt',
     'emon_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBench/Rome_SKX_CLX/CLX8280M/qanet-standalone-inference-sf1/aibench-20190913131334426676/dummy-0-7f9b948cdc-twhzb/perf-0-5cdddf775b-rsjm9/emon-13092019132028'},
]

duality_phase05 = [
    {'name': 'duality-config4-standard_56i_1cpi_defcf_defuf_2666df_proxy','perf': 1276,
     'agg_secs': 0.04, 'start': None, 'stop': None, 'metrics': 'skx-2s-proxy-only.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/duality_phase0.5',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/duality-standard-emon/aibench-20190912153440015185/dummy-0-594cc76d64-rjrvk/perf-0-c49656859-5nddj/emon-12092019154047'},
    {'name': 'duality-config4-standard_28i_1cpi_defcf_defuf_2666df_proxy','perf': 731,
     'agg_secs': 0.04, 'start': None, 'stop': None, 'metrics': 'skx-2s-proxy-only.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/duality_phase0.5',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/duality-standard-emon/aibench-20190913105803541781/dummy-0-767655f4-2wbc5/perf-0-69864749df-ff24g/emon-13092019110340'},
    {'name': 'duality-config4-standard_1i_56cpi_defcf_defuf_2666df_proxy','perf': 27,
     'agg_secs': 0.04, 'start': None, 'stop': None, 'metrics': 'skx-2s-proxy-only.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/duality_phase0.5',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/duality-standard-emon/aibench-20190912145000906610/dummy-0-869f46f8c4-8f4sk/perf-0-7fc49d8cd9-dx244/emon-12092019145644'},

    {'name': 'duality-config4-experimental_56i_1cpi_defcf_defuf_2666df_proxy','perf': 1253,
     'agg_secs': 0.04, 'start': None, 'stop': None, 'metrics': 'skx-2s-proxy-only.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/duality_phase0.5',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/duality-experimental-emon/aibench-20190912163528868048/dummy-0-c6d9c9655-jl9pq/perf-0-796c5464d8-trgdb/emon-12092019164246'},
    {'name': 'duality-config4-experimental_28i_1cpi_defcf_defuf_2666df_proxy','perf': 695,
     'agg_secs': 0.04, 'start': None, 'stop': None, 'metrics': 'skx-2s-proxy-only.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/duality_phase0.5',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/duality-experimental-emon/aibench-20190919122717822792/dummy-0-6774dbd784-dhrsh/perf-0-86766bb7b7-rf7ld/emon-19092019123338'},
    {'name': 'duality-config4-experimental_1i_56cpi_defcf_defuf_2666df_proxy','perf': 4.3,
     'agg_secs': 0.04, 'start': None, 'stop': None, 'metrics': 'skx-2s-proxy-only.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/duality_phase0.5',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/duality-experimental-emon/aibench-20190916110119655354/dummy-0-7fcbc697dd-j4zq8/perf-0-55c6b75695-658cn/emon-16092019110645'},
]


aibt_clx_2933 = [
    {'name': 'inception-v3-imagenet-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     #'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/combined',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-194923-inception_v3_imagenet_float32'},
    {'name': 'inception-v4-imagenet-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-195111-inception_v4_imagenet_float32'},
    {'name': 'rfcn-resnet-101-coco-int8_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-195251-rfcn_resnet_101_coco_int8'},
    {'name': 'dcgan-cifar10data-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-200316-dcgan_cifar10data_float32'},
    {'name': 'mtcc-lfw-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-200407-mtcc_lfw_float32'},
    {'name': 'unet-nodatalayer-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-203741-unet_nodatalayer_float32'},
    {'name': 'ncf-ml-1m-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-203837-ncf_ml-1m_float32'},
    {'name': 'resnet-50-v1-5-imagenet-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-220744-resnet_50_v1_5_imagenet_float32'},
    {'name': 'resnet-50-v1-5-imagenet-int8_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-220929-resnet_50_v1_5_imagenet_int8'},
    {'name': 'ssd-resnet-34-nodatalayer-int8_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-221054-ssd_resnet_34_nodatalayer_int8'},
    {'name': 'inception-resnet-v2-imagenet-int8_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-221405-inception_resnet_v2_imagenet_int8'},
    {'name': 'rfcn-resnet-101-coco-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-221502-rfcn_resnet_101_coco_float32'},
    {'name': 'facenet-lfw-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-224622-facenet_lfw_float32'},
    {'name': 'densenet-169-imagenet-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-225101-densenet_169_imagenet_float32'},
    {'name': 'lm-1b-wmt11-monolingual-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-225221-lm_1b_wmt11_monolingual_float32'},
    {'name': 'resnet-50-v1-imagenet-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-225300-resnet_50_v1_imagenet_float32'},
    {'name': 'resnet-50-v1-imagenet-int8_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-225447-resnet_50_v1_imagenet_int8'},
    {'name': 'mobilenet-v1-imagenet-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-225607-mobilenet_v1_imagenet_float32'},
    {'name': 'wide-and-deep-criteo-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190919-225720-wide_and_deep_criteo_float32'},
    {'name': 'resnet-101-v1-imagenet-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-022029-resnet_101_v1_imagenet_float32'},
    {'name': 'resnet-101-v1-imagenet-int8_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-022228-resnet_101_v1_imagenet_int8'},
    {'name': 'inception-v3-imagenet-int8_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-022350-inception_v3_imagenet_int8'},
    {'name': 'fasterrcnn-resnet-50-v1-coco-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-022514-fasterrcnn_resnet_50_v1_coco_float32'},
    {'name': 'ssd-mobilenet-v1-coco-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-032206-ssd_mobilenet_v1_coco_float32'},
    {'name': 'inception-v4-imagenet-int8_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-033720-inception_v4_imagenet_int8'},
    {'name': 'draw-mnistdata-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-033820-draw_mnistdata_float32'},
    {'name': 'fasterrcnn-resnet-50-v1-coco-int8_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-033933-fasterrcnn_resnet_50_v1_coco_int8'},
    {'name': 'maskrcnn-resnet-101-v1-coco-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-051152-maskrcnn_resnet_101_v1_coco_float32'},
    {'name': 'ssd-resnet-34-nodatalayer-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-051231-ssd_resnet_34_nodatalayer_float32'},
    {'name': 'ssd-mobilenet-v1-coco-int8_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-051952-ssd_mobilenet_v1_coco_int8'},
    {'name': 'deepmind-wavenet-nsynth-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-052043-deepmind_wavenet_nsynth_float32'},
    {'name': 'inception-resnet-v2-imagenet-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-052308-inception_resnet_v2_imagenet_float32'},
    {'name': 'gnmt-4-wmt16-ger-eng-float32_56i_2cpi_defcf_defuf_2933df_default','perf': None,
     'agg_secs': 3.5, 'start': None, 'stop': None, 'metrics': 'clx-2s.xml',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_clx_2933',
     'emon_dir': '/mnt/nvme_nfs_share/AIBench_shared_disk/Scenario/AIBT_emon_mpiotrow/20190920-052422-gnmt_4_wmt16_ger_eng_float32'},
]

aibt_121619 = [{
     'type': 'aibt',
     'search_dir': '/mnt/san03RAID1/data_repo/Benchmarks/AIBT/Clustering_CLX8280M',
     'results_dir': '/mnt/san03RAID1/users/mablackm/aibench_emon/results/aibt_121619',
     'manual_start_stop': {}
}]

# %%
from datetime import datetime
from glob import glob
import numpy as np
import os
import pandas as pd
import time
import re
import subprocess
import xml.etree.ElementTree as ET
import statistics
import math
import numexpr
import copy
import sys
import queue
import multiprocessing
from multiprocessing import Pool
import xlsxwriter
from xlsxwriter.utility import xl_rowcol_to_cell
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

# Necessary to not truncate column data in pandas
# Used for long strings (such as HTML links) and floats (such as timestamps)
pd.set_option('display.max_colwidth', -1)

# datetime format
FMT = '%m/%d/%Y %H:%M:%S.%f'

def printmd(string, color=None):
    colorstr = "<span style='color:{}'>{}</span>".format(color, string)
    display(Markdown(colorstr))

manager = multiprocessing.Manager()
errors = manager.list()
warnings = manager.list()

def log(level, message):
    global warnings
    global errors
    id = os.getpid()
    if "warning" in level.lower():
        warnings.append(message)
        print("[WARN][%d]\t"%(id), message)
    elif "error" in level.lower():
        errors.append(message)
        print("[ERROR][%d]\t"%(id), message)
    else:
        print("[INFO][%d]\t"%(id), message)

# %%
perf_keyphrases = ['Total words per second', 'Throughput (images/second)', 'Throughput (words/second)',
                   'Throughput (queries/second)', 'Total activity recognition fps', 'Throughput (streams/second)',
                   'Total compute infer fps', 'Total E2E detect fps', 'Throughput (samples/second)',
                   'Average Rate (images/second)', 'Total images processed per second (Throughput)']
def create_workload_list(workload_list):
    expanded_list = []
    existing_runs = {}
    for entry in workload_list:
        if 'emon_dir' in entry or 'edp_file' in entry:
            expanded_list.append(entry)
        elif entry['type'] == 'aibench':
            root_dir = entry['search_dir']
            for node_dir in glob(root_dir + '/*/'):
                match_obj = re.search(r'data_collection_(.*)-(fmx\d+)', node_dir)
                if match_obj is None:
                    continue
                timestamp = match_obj.group(1)
                node = match_obj.group(2)
                for workload_dir in glob(node_dir + '/*/'):
                    workload = workload_dir.split('/')[-2]
                    for config_dir in glob(workload_dir + '/*/'):
                        config = config_dir.split('/')[-2]
                        perf_type = config.split('_')[-1]
                        if 'flops' in perf_type.lower():
                            metrics = 'skx-2s-flops-only.xml'
                            agg_secs = 0.02  # 10ms => 20ms
                        elif 'memory' in perf_type.lower():
                            metrics = 'skx-2s-memory-only.xml'
                            agg_secs = 0.01  # 5ms => 10ms
                        elif 'proxy' in perf_type.lower():
                            metrics = 'skx-2s-proxy-only.xml'
                            agg_secs = 0.04  # 10ms => 40ms
                        else:
                            metrics = 'skx-2s.xml'
                            agg_secs = 3.0  # 100ms => 3sec
                        matches = re.findall(r'\d+', config)
                        instances = matches[0]
                        cores_per_instance = matches[1]
                        core_freq = str(float(matches[2]) / 1000.0)
                        uncore_freq = str(float(matches[3]) / 1000.0)
                        dram_freq = matches[4]
                        run = "%s_%si_%scpi_%scf_%suf_%sdf_%s"%(workload, instances, cores_per_instance,
                                                                core_freq, uncore_freq, dram_freq, perf_type)
                        for namespace_dir in glob(config_dir + '/*/'):
                            perf = match_obj = None
                            result_log = namespace_dir + 'result.log'
                            #TODO - need standardized perf reporting format to parse
                            if os.path.isfile(result_log):
                                fp = open(result_log, 'rt')
                                contents = fp.read()
                                fp.close()
                                for keyphrase in perf_keyphrases:
                                    if keyphrase in contents:
                                        regex_phrase = keyphrase.replace(r'(', r'\(').replace(r')', r'\)').replace(r'/', r'\/')
                                        match_obj = re.search(regex_phrase + r'.*\b(\d+\.\d*)', contents)
                                        break
                            if match_obj is not None:
                                perf = match_obj.group(1)
                            else:
                                log("warning", "%s couldn't parse performance from %s"%(run, result_log))
                            for instance_dir in glob(namespace_dir + '/*/'):
                                last_level_instance_dir = instance_dir.split('/')[-2]
                                if perf_type.lower() in last_level_instance_dir.lower():
                                    for perf_dir in glob(instance_dir + '/*/'):
                                        for emon_dir in glob(perf_dir + '/*/'):
                                            emon_file = emon_dir + 'emon.log'
                                            if not os.path.isfile(emon_file):
                                                continue
                                            emon_bytes = os.path.getsize(emon_file)
                                            start = None
                                            stop = None
                                            if 'manual_start_stop' in entry:
                                                if run in entry['manual_start_stop']:
                                                    start = entry['manual_start_stop'][run]['start']
                                                    stop = entry['manual_start_stop'][run]['stop']
                                            new_entry = {
                                                'name':       run,
                                                'start':      start,
                                                'stop':       stop,
                                                'metrics':    metrics,
                                                'perf':       perf,
                                                'agg_secs':   agg_secs,
                                                'emon_dir':   emon_dir.rstrip('/'),
                                                'node':       node,
                                                'timestamp':  timestamp,
                                                'emon_bytes': emon_bytes,
                                                'results_dir': entry['results_dir'],
                                            }
                                            # there may be duplicate runs, take the most recent
                                            if run in existing_runs:
                                                log("warning", "Removing duplicate run %s"%(run))
                                                expanded_list = [i for i in expanded_list if not (i['name'] == run)] 
                                            else:
                                                existing_runs[run] = emon_dir
                                            expanded_list.append(new_entry)
        elif entry['type'] == 'aibt':
            root_dir = entry['search_dir']
            for run_dir in glob(root_dir + '/Run*/'):
                run = run_dir.split('/')[-2]
                for workload_dir in glob(run_dir + '/*/'):
                    workload = workload_dir.split('/')[-2].replace('_', '-')
                    for config_dir in glob(workload_dir + '/aibt*/'):
                        config = config_dir.split('/')[-2]
                        node = config.split('-')[-1]
                        model_precision = config.split('-')[-3]
                        model = config.split('-')[-4]
                        
                        perf_type = 'default'
                        perf = None
                        metrics = 'clx-2s.xml'
                        agg_secs = 3.5
                        instances = '56'
                        cores_per_instance = '1'
                        core_freq = 'def'
                        uncore_freq = 'def'
                        dram_freq = '2933'
                        full_run = "%s-%s-%s-%s_%si_%scpi_%scf_%suf_%sdf_%s"%(workload, model, model_precision, run,
                                                                              instances, cores_per_instance,core_freq,
                                                                              uncore_freq, dram_freq, perf_type)
                        for namespace_dir in glob(config_dir + '0/*/'):
                            for emon_dir in glob(namespace_dir + 'plugins/emon/'):
                                emon_file = emon_dir + 'emon.log'
                                if not os.path.isfile(emon_file):
                                    log("warning", "Could not find emon.log in %s"%(emon_dir))
                                    continue
                                emon_bytes = os.path.getsize(emon_file)
                                start = None
                                stop = None
                                if 'manual_start_stop' in entry:
                                    if run in entry['manual_start_stop']:
                                        start = entry['manual_start_stop'][run]['start']
                                        stop = entry['manual_start_stop'][run]['stop']
                                new_entry = {
                                    'name':              full_run,
                                    'start':             start,
                                    'stop':              stop,
                                    'metrics':           metrics,
                                    'perf':              perf,
                                    'agg_secs':          agg_secs,
                                    'emon_dir':          emon_dir.rstrip('/'),
                                    'node':              node,
                                    'emon_bytes':        emon_bytes,
                                    'results_dir':       entry['results_dir'],
                                    'model_precision':   model_precision,
                                    'model':             model,
                                    'run_count':         run,
                                    'workload_name':     workload,
                                }
                                # there may be duplicate runs, take the most recent
                                if full_run in existing_runs:
                                    log("warning", "Removing duplicate run %s"%(full_run))
                                    expanded_list = [i for i in expanded_list if not (i['name'] == full_run)] 
                                else:
                                    existing_runs[full_run] = emon_dir
                                expanded_list.append(new_entry)
        elif entry['type'] == 'edp':
            root_dir = entry['search_dir']
            for root, dirs, files in os.walk(root_dir):
                path = root.split(os.sep)
                for file in files:
                    file_path = root + '/' + file
                    name = file_path.replace(root_dir, '').lstrip('/').replace('/','-').replace(' ', '-').replace('.xlsx', '').replace('emon.dat', '')
                    if file == 'emon.dat':
                        new_entry = {
                            'name':        name,
                            'start':       None,
                            'stop':        None,
                            'metrics':     'skx-2s.xml',
                            'perf':        None,
                            'agg_secs':    3.0,
                            'emon_dir':    root,
                            'node':        None,
                            'timestamp':   None,
                            'emon_bytes':  os.path.getsize(file_path),
                            'results_dir': entry['results_dir'],
                        }
                        expanded_list.append(new_entry)
                    elif '.xlsx' in file:
                        include_file = file_path.replace(".xlsx", ".include")
                        exclude_file = file_path.replace(".xlsx", ".exclude")
                        if not os.path.isfile(include_file) and not os.path.isfile(exclude_file):
                            xl = pd.ExcelFile(file_path)
                            if 'emonV' not in xl.sheet_names or 'system view' not in xl.sheet_names:
                                os.mknod(exclude_file)
                                continue
                            else:
                                os.mknod(include_file)
                        
                        if os.path.isfile(include_file):
                            new_entry = {
                                'name':        name,
                                'start':       None,
                                'stop':        None,
                                'metrics':     'skx-2s.xml',
                                'perf':        None,
                                'agg_secs':    1.0,
                                'emon_dir':    root,
                                'edp_file':    file,
                                'node':        None,
                                'timestamp':   None,
                                'emon_bytes':  os.path.getsize(file_path),
                                'results_dir': entry['results_dir'],
                            }
                            expanded_list.append(new_entry)
        elif entry['type'] == 'kafka-emulator':
            #  open summary file to get namespaces
            csv = pd.read_csv(entry['summary_file'], index_col=0)
            
            #  navigate each namespace directory structure
            root_dir = entry['search_dir']
            for namespace_dir in glob(root_dir + '/*/'):
                namespace = namespace_dir.split('/')[-2]
                if namespace in csv['STORAGE_MEDIUM'].values:
                    for instance_dir in glob(namespace_dir + '/*/'):
                        instance = instance_dir.split('/')[-2]
                        if 'e2e-kafkabroker' in instance and 'configemon' in instance:
                            for perf_dir in glob(instance_dir + '/*/'):
                                for emon_dir in glob(perf_dir + '/*/'):
                                    emon_file = emon_dir + 'emon.log'
                                    if os.path.isfile(emon_file):
                                        new_entry = {
                                            'name':        'kafka_' + namespace + '_' + instance,
                                            'namespace':   namespace,
                                            'start':       None,
                                            'stop':        None,
                                            'metrics':     'skx-2s.xml',
                                            'perf':        None,
                                            'agg_secs':    entry['agg_secs'],
                                            'emon_dir':    emon_dir,
                                            'node':        None,
                                            'timestamp':   None,
                                            'emon_bytes':  os.path.getsize(emon_file),
                                            'results_dir': entry['results_dir'],
                                        }
                                        for key,val in csv[csv['STORAGE_MEDIUM'] == namespace].to_dict('list').items():
                                            new_entry[key] = val[0]
                                        expanded_list.append(new_entry)
            
        
    sorted_list = sorted(expanded_list, key = lambda x: x['emon_bytes'])
    return sorted_list

# %% [markdown]
# # # CONVERT RAW EMON TO CSV

# %%
def tryint(s):
    try:
        return int(s)
    except ValueError:
        return s
     
def alphanum_key(s):
    """ Turn a string into a list of string and number chunks.
        "z23a" -> ["z", 23, "a"]
    """
    return [ tryint(c) for c in re.split('([0-9]+)', s) ]

def get_cpu(cpu_family):
    if 'Skylake' in cpu_family:
        return 'skx'
    elif 'Broadwell' in cpu_family:
        return 'bdx'
    elif 'Cascadelake' in cpu_family:
        return 'clx'
    elif 'AMD' in cpu_family:
        return 'amd'
    else:
        return 'unknown'

def parse_system_info(file):
    # (if there is only one socket package count doesn't seem to be explicitely stated)
    system_info = {
        'system.sockets.count': 2,
        'system.sockets[0].cores.count': 0,
        'system.sockets[0][0].size': 0,
        'system.sockets[1].cores.count': 0,
        'system.sockets[1][0].size': 0,
        'DRAM freq': 0,
        'dram_channels': 0
    }  
    for line in file:
        if 'TSC Freq' in line:
            m = re.search('\D(\d+\.\d*)', line)
            system_info['system.tsc_freq'] = float(m.group(1)) * 1e6
        if 'cpu_family' in line:
            line = line.replace('NaN','').rstrip()
            m = re.search('\.+ (.*)', line)
            system_info['cpu_family'] = m.group(1)
            system_info['cpu_short'] = get_cpu(m.group(1))
        elif 'Number of Packages' in line:
            m = re.search('\D(\d+)', line)
            system_info['system.sockets.count'] = float(m.group(1))
        elif 'Cores Per Package' in line:
            m = re.search('\D(\d+)', line)
            for j in range(int(system_info['system.sockets.count'])):
                system_info['system.sockets[' + str(j) + '].cores.count'] = m.group(1)
        elif 'Threads Per Core' in line:
            m = re.search('\D(\d+)', line)
            # Seems we are only using [0][0] in EDP, so this iteration maynot be necessary
            for j in range(int(system_info['system.sockets.count'])):
                system_info['system.sockets[' + str(j) +'][0].size'] = m.group(1)
        elif 'number_of_online_processors' in line:
            m = re.search('\D(\d+)', line)
            system_info['number_of_online_processors'] = float(m.group(1))
        elif 'Total Number of Ranks' in line:  # on this Channel
            system_info['dram_channels'] = system_info['dram_channels'] + 1
        elif 'CPU Freq (detected)' in line:
            m = re.search('\D(\d+\.\d*)', line)
            system_info['core freq'] = float(m.group(1)) / 1000.0
        elif 'UFS Freq (limit)' in line:
            m = re.search('\D(\d+\.\d*)', line)
            system_info['uncore freq'] = float(m.group(1)) / 1000.0
        elif 'Speed' in line:
            m = re.search('\D(\d+)MHz', line)
            system_info['DRAM freq'] = m.group(1)

    # assume dram channels & speed if that info isn't in emonv
    if system_info['dram_channels'] == 0:
        if 'cpu_short' in system_info:
            if system_info['cpu_short'] == 'skx':
                system_info['dram_channels'] = 12
            elif system_info['cpu_short'] == 'bdx':
                system_info['dram_channels'] = 8
            elif system_info['cpu_short'] == 'clx':
                system_info['dram_channels'] = 12
            elif system_info['cpu_short'] == 'amd':
                system_info['dram_channels'] = 16
        else:
            system_info['dram_channels'] = 1
            
    if system_info['DRAM freq'] == 0:
        if 'cpu_short' in system_info:
            if system_info['cpu_short'] == 'skx':
                system_info['DRAM freq'] = 2666
            elif system_info['cpu_short'] == 'bdx':
                system_info['DRAM freq'] = 2133
            elif system_info['cpu_short'] == 'clx':
                system_info['DRAM freq'] = 2666
            elif system_info['cpu_short'] == 'amd':
                system_info['DRAM freq'] = 2666
        else:
            system_info['DRAM freq'] = 2666
            
    return system_info

# %%
def convert_from_edp(entry):
    run = entry['name']
    dir = entry['emon_dir']
    file = dir + '/' + entry['edp_file']
    sum_file = dir + "/" + run + "_emon_sum.csv"
    start_time = time.time()
    
    if os.path.isfile(sum_file):
        if OVERWRITE == False:
            return
        else:
            os.remove(sum_file)
    log("info", "Converting %s from edp to csv..."%(run))
    
    # parse emonv
    emonv = pd.read_excel(file, sheet_name='emonV', index_col=None, header=None)
    sys_info = parse_system_info(emonv.to_string().splitlines())
    
    # parse emon
    data = pd.read_excel(file, index_col=0, sheet_name='system view', na_values=['Infinity', 'NaN'])
    data = data.transpose()
    #drop_columns = [col for col in data.columns if 'metric_' in col]
    #data = data.drop(drop_columns, axis=1)  # remove calculated metrics (they're re-calculated later)
    data = data.loc[['aggregated']]  # get just avg
    data = data.reset_index(drop=True)
    
    # add emonv to emon
    for key,val in sys_info.items():
        data[key] = val
        
    # add other key columns
    data['duration'] = 1.0
    data['timestamp'] = None
    data['interval'] = 0
    data['TSC'] = data['number_of_online_processors'] * data['system.tsc_freq'] * data['duration']
    data['run'] = run
    data['workload'] = run
    data['instances'] = 1
    data['cores per instance'] = data['number_of_online_processors']
    data['cores used'] = data['number_of_online_processors']
    data['metrics'] = 'default'
    data['raw_emon'] = file
    data['performance'] = entry['perf']
    data['suggested_start'] = 0
    data['suggested_stop'] = 0
    data['suggested_start_confidence'] = 'high'
    data['suggested_stop_confidence'] = 'high'
    
    # write to file
    data.to_csv(sum_file, chunksize=1e6)

    log("info", "Converting %s from edp to csv took %d secs"%(run, time.time() - start_time))

# %%
def convert_to_csv(entry):
    if 'edp_file' in entry:
        convert_from_edp(entry)
        return
    
    run = entry['name']
    dir = entry['emon_dir']
    file = None
    emonv_file = None
    sum_file = dir + "/" + run + "_emon_sum.csv"
    
    if os.path.isfile(sum_file):
        if OVERWRITE == False:
            return
        else:
            os.remove(sum_file)
    log("info", "Converting %s to csv..."%(run))
    
    possible_files = [dir + '/emon.log', dir + '/emon.dat', dir + '/emon.txt']
    for possible_file in possible_files:
        if os.path.isfile(possible_file):
            file = possible_file
            break
    if file is None:
        log("error", "Could not find emon.log/.dat/.txt in %s"%(dir))
        return
    
    possible_files = [dir + '/../emonv.log', dir + '/../emonv.dat', dir + '/../emonv.txt',
                      dir + '/../emon-v.log', dir + '/../emon-v.dat', dir + '/../emon-v.txt',
                      dir + '/emonv.log', dir + '/emonv.dat', dir + '/emonv.txt',
                      dir + '/emon-v.log', dir + '/emon-v.dat', dir + '/emon-v.txt']
    for possible_file in possible_files:
        if os.path.isfile(possible_file):
            emonv_file = possible_file
            break
    if emonv_file is None:
        log("error", "Cound not find emonv in %s or its parent"%(dir))
        return
    
    emonv = open(emonv_file, 'r')
    sys_info = parse_system_info(emonv)
    emonv.close()

    output_bytes = subprocess.check_output("grep -e '-----' -e '=====' %s | wc -l"%(file), shell=True)
    expected_samples = int(output_bytes.decode("utf-8"))
    #print("\tFound %d samples in file %s"%(expected_samples, file))

    # initialize variables
    window_duration = 5  # secs to keep running avg
    window_size = 1e6  # intervals to keep running avg;starting value, will be updated once we know duration of interval
    instr_mean = None
    instr_stddev = None
    req_mean_mult = 2  # multiple that a data point must from avg to be considered significant
    instr_window = queue.Queue() # save last samples to try to find start/stop of workload
    #instr_window_sq = queue.Queue() # save last samples^2 to try to find start/stop of workload
    possible_starts = []
    possible_stops =  []
    sum_dict = {}
    per_core_dict = {}
    linenum = 0  # line number
    samplenum = -1  # sample number
    current_timestamp = None
    last_timestamp = None
    duration = None
    cum_duration = 0
    tsc = None
    timestamp = True  # flag to indicate next line is timestamp

    # read in txt
    start_time = time.time()
    with open(file) as fp:
        #print("\tProcessing EMON samples...", end='', flush=True)
        for line in fp:
            linenum += 1
            if linenum < 3: #ignore first couple lines (EMON version and blank line)
                continue
            elif re.search('----------', line) or re.search('==========', line):  # break between samples (next line is timestamp)
                timestamp = True
            elif timestamp == True:  # save timestamp
                timestamp = False
                samplenum += 1
                last_timestamp = current_timestamp
                current_timestamp = line.strip()

                if re.search("real", current_timestamp): # end of samples
                    break

                if last_timestamp is not None:
                    duration = (datetime.strptime(current_timestamp, FMT) - datetime.strptime(last_timestamp, FMT)).total_seconds()
                    cum_duration += duration
                    # count of total clocks for all cores for this interval
                    tsc = float(sys_info['number_of_online_processors']) * float(sys_info['system.tsc_freq']) * duration
                    # initialize queue to hold x secs of samples
                    if window_size == 1e6:
                        window_size = int(window_duration / duration)

                sum_dict[samplenum] = {'timestamp': current_timestamp, 'duration': duration, 'TSC': tsc, 'interval': samplenum}
                sum_dict[samplenum] = {**sum_dict[samplenum], **sys_info}
                if GENERATE_PER_CORE:
                    per_core_dict[samplenum] = {'timestamp': current_timestamp, 'duration': duration, 'TSC': tsc, 'interval': samplenum}
                    per_core_dict[samplenum] = {**per_core_dict[samplenum], **sys_info}

            else:  # save samples
                sample = line.split()
                counter = sample[0]
                clocks = sample[1]
                sample.remove(counter)  # remove counter name
                sample.remove(clocks)  # remove count of clocks
                sample = [int(i.replace(',','')) for i in sample]  # convert to ints and remove commas
                total = sum(sample)
                #average = sum(sample)/len(sample)
                length = len(sample)

                #add to dfs
                sum_dict[samplenum][counter] = total
                if GENERATE_PER_CORE:
                    for i in range(0, length):
                        per_core_counter = "%s_%i"%(counter, i)
                        per_core_dict[samplenum][per_core_counter] = sample[i]

                # save possible start/stop samples
                #if counter == 'INST_RETIRED.ANY':
                #    # save instruction count
                #    if instr_window.qsize() >= window_size:
                #        instr_window.get()
                #        #instr_window_sq.get()
                #
                #    instr_window.put(float(total))
                #    #instr_window_sq.put(float(total) * float(total))
                #
                #    # update running mean & stddev
                #    if samplenum >= window_size:
                #        instr_mean = sum(list(instr_window.queue)) / window_size
                #        #instr_stddev = math.sqrt((sum(list(instr_window_sq.queue)) / window_size) - (instr_mean * instr_mean))
                #
                #        #check for possible inflection (change by more than x times mean)
                #        if total >= (instr_mean * req_mean_mult):
                #            possible_starts.append(samplenum)
                #        if total <= (instr_mean / req_mean_mult):
                #            possible_stops.append(samplenum)

    # no duration for first interval so just copy 2nd interval
    sum_dict[0]['duration'] = sum_dict[1]['duration']
    sum_dict[0]['TSC'] = sum_dict[1]['TSC']
    if GENERATE_PER_CORE:
        per_core_dict[0]['duration'] = per_core_dict[1]['duration']
        per_core_dict[0]['TSC'] = per_core_dict[1]['TSC']
    
    processing_end_time = time.time()
    #print("%d secs"%(processing_end_time - start_time))

    #print("\tConverting to DataFrame...", end='', flush=True)
    # need to convert to df because not every interval in dict has same columns (keys). df fills in with nan.
    sum_df = pd.DataFrame.from_dict(sum_dict, "index")
    sorted_cols = list(sum_df.columns.values).sort(key=alphanum_key)
    sum_df = sum_df.reindex(columns=sorted_cols)
    if GENERATE_PER_CORE:
        per_core_df = pd.DataFrame.from_dict(per_core_dict, "index")
        sorted_cols = list(per_core_df.columns.values).sort(key=alphanum_key)
        per_core_df = per_core_df.reindex(columns=sorted_cols)
    convert_end_time = time.time()
    #print("%d secs"%(convert_end_time - processing_end_time))

    
    ## find potential workload start point
    #algo_iterations = 3 # run algorithm a few times, widening criteria each time
    ## max interval distance between potential start/stop points to be considered 'in a row' (allows for errant spikes)
    #max_point_gap = 3  # determined by trial & error; not a perfect scheme
    skip_percent = 10  # skip this % in the beginning to jump ahead of most noise from starting harness/workload
    ## must have this many start/stop points in a row (each <= max_point_gap from eachother)
    ##min_points_in_row = int(1 / sum_df['duration'].mean())  # determined by trial & error; not a perfect scheme
    #min_points_in_row = window_size
    #true_start = entry['start']
    #start_iterations = 1  # fewer iterations of algo means higher confidence
    #if true_start is None:
    #    for i in range(algo_iterations):
    #        #print(max_point_gap, " : ", min_points_in_row)
    #        starts_in_row = 0
    #        beginning_of_row = None
    #        last_start = None
    #        for possible_start in possible_starts:
    #            if possible_start >= int(sum_df['interval'].max() * (skip_percent / 100.0)):
    #                #print(possible_start, " -> ", starts_in_row)
    #                if beginning_of_row is None:
    #                    beginning_of_row = possible_start
    #
    #                if last_start is None or possible_start - last_start <= max_point_gap:  # count as "row" of stops if points are <= y apart
    #                    starts_in_row += 1
    #                else:
    #                    if starts_in_row >= min_points_in_row: # stop when we find first sample with x in a row that are <= y apart
    #                        break
    #                    beginning_of_row = possible_start
    #                    starts_in_row = 1
    #
    #                last_start = possible_start
    #
    #        if starts_in_row >= min_points_in_row: # stop when we find first sample with x in a row that are <= y apart
    #            if beginning_of_row < (len(sum_df.index) - window_size):  # if we're within a window_size of the end of the WL, don't count it
    #                true_start = beginning_of_row
    #                break
    #
    #        max_point_gap = int(max_point_gap * 2)
    #        min_points_in_row = int(min_points_in_row / 2)
    #        start_iterations += 1


    ## find potential workload stop point
    ## max interval distance between potential start/stop points to be considered 'in a row' (allows for errant spikes)
    #max_point_gap = 3  # determined by trial & error; not a perfect scheme
    ## must have this many start/stop points in a row (each <= max_point_gap from eachother)
    ##min_points_in_row = int(5 / sum_df['duration'].mean())  # determined by trial & error; not a perfect scheme
    #min_points_in_row = window_size
    #true_stop = entry['stop']
    #stop_iterations = 1  # fewer iterations of algo means higher confidence
    #if true_stop is None:
    #    for i in range(algo_iterations):
    #        stops_in_row = 0
    #        beginning_of_row = None
    #        last_stop = None
    #       for possible_stop in possible_stops:
    #            if true_start is not None and possible_stop <= (true_start + window_size): # don't pick a stop that is less than or within one window of the start
    #                continue
    #
    #            if beginning_of_row is None:
    #                beginning_of_row = possible_stop
    #
    #            if last_stop is None or possible_stop - last_stop <= max_point_gap:  # count as "row" of stops if points are <= y apart
    #                stops_in_row += 1
    #            else:
    #                if stops_in_row >= min_points_in_row: # stop when we find first sample with x in a row that are <= y apart
    #                    break
    #                beginning_of_row = possible_stop
    #                stops_in_row = 1
    #
    #            last_stop = possible_stop
    #
    #        if stops_in_row >= min_points_in_row: # stop when we find first sample with x in a row that are <= y apart
    #            true_stop = beginning_of_row #+ int(min_points_in_row / 2)
    #            break
    #
    #        max_point_gap = int(max_point_gap * 2)
    #        min_points_in_row = int(min_points_in_row / 2)
    #        stop_iterations += 1

            
    # define a name for the confidence level based on how many iterations it took to find a start/stop
    confidence_dict = {1: "high", 2: "med", 3: "low"}
    
    #if start_iterations in confidence_dict:
    #    start_confidence = confidence_dict[start_iterations]
    #else:
    start_confidence = "no"
        
    #if stop_iterations in confidence_dict:
    #    stop_confidence = confidence_dict[stop_iterations]
    #else:
    stop_confidence = "no"
            
            
    ## if didn't find suggested start/stop, set them to beginning or end of workload
    #if true_start is None:
    #    true_start = 0
    #if true_stop is None:
    #    true_stop = len(sum_df.index) - 1
    
    # naively just cut off first and last x%
    true_start = int(sum_df['interval'].max() * (skip_percent / 100.0))
    true_stop = sum_df['interval'].max() - true_start
            
    # temporary to cleanup dirs
    #output_bytes = subprocess.check_output("rm -f %s/*.csv"%(dir), shell=True)
    
    # add some tags & constants
    tok = run.split('_')
    sum_df['run'] = run
    
    if len(tok) >= 7:
        sum_df['workload'] = tok[0]
        sum_df['instances'] = int(tok[1].strip('i'))
        sum_df['cores per instance'] = int(tok[2].strip('cpi'))
        sum_df['core freq'] = str(tok[3].strip('cf').replace('de', 'default'))
        sum_df['uncore freq'] = str(tok[4].strip('uf').replace('de', 'default'))
        sum_df['DRAM freq'] = int(tok[5].strip('df'))
        sum_df['metrics'] = tok[6]
    else:
        sum_df['workload'] = sum_df['run']
        sum_df['instances'] = 1
        sum_df['cores per instance'] = sum_df['number_of_online_processors']
        sum_df['metrics'] = 'default'
    
    sum_df['cores used'] = sum_df['instances'] * sum_df['cores per instance']
    sum_df['raw_emon'] = file
    sum_df['performance'] = entry['perf']
    sum_df['suggested_start'] = true_start
    sum_df['suggested_stop'] = true_stop
    sum_df['suggested_start_confidence'] = start_confidence
    sum_df['suggested_stop_confidence'] = stop_confidence
    
    #add entry items to df
    for key,val in entry.items():
        sum_df[key] = val
        
    if GENERATE_PER_CORE:
        per_core_df['run'] = run
        per_core_df['workload'] = tok[0]
        per_core_df['instances'] = int(tok[1].strip('i'))
        per_core_df['cores per instance'] = int(tok[2].strip('cpi'))
        per_core_df['cores used'] = per_core_df['instances'] * per_core_df['cores per instance']
        per_core_df['core freq'] = str(tok[3].strip('cf').replace('de', 'default'))
        per_core_df['uncore freq'] = str(tok[4].strip('uf').replace('de', 'default'))
        per_core_df['DRAM freq'] = int(tok[5].strip('df'))
        per_core_df['metrics'] = tok[6]
        per_core_df['raw_emon'] = file
        per_core_df['performance'] = entry['perf']
        per_core_df['suggested_start'] = true_start
        per_core_df['suggested_stop'] = true_stop
        per_core_df['suggested_start_confidence'] = start_confidence
        per_core_df['suggested_stop_confidence'] = stop_confidence
        for key,val in entry.items():
            per_core_df[key] = val
    
    # write to csv
    sum_df.to_csv(sum_file, chunksize=1e6)
    if GENERATE_PER_CORE:
        per_core_file = dir + "/" + run + "_emon_per_core.csv"
        per_core_df.to_csv(per_core_file, chunksize=1e6)

    log("info", "Converted %s to csv in %d secs with %s confidence start %d & %s confidence stop %d"%(
          run, time.time() - start_time, start_confidence, true_start, stop_confidence, true_stop))

# %% [markdown]
# # # AGGREGATE

# %%
# most of the avg columns are added metrics just in case
avg_cols = ['metric_Arithmetic Intensity', 'metric_GFLOPS/s', 'metric_FLOPS','metric_FLOPS.256B_PACKED_SINGLE(%)',
            'metric_FLOPS.256B_PACKED_DOUBLE(%)', 'metric_FLOPS.512B_PACKED_SINGLE(%)', 'metric_FLOPS.512B_PACKED_DOUBLE(%)',
            'metric_CPU operating frequency (in GHz)', 'metric_CPU utilization %', 'metric_CPU utilization% in kernel mode',
            'metric_CPI', 'metric_kernel_CPI', 'metric_EMON event mux reliability% (>95% good)',
            'metric_branch mispredict ratio', 'metric_loads per instr', 'metric_stores per instr',
            'metric_locks retired per instr', 'metric_uncacheable reads per instr',
            'metric_streaming stores (full line) per instr', 'metric_streaming stores (partial line) per instr',
            'metric_L1D MPI (includes data+rfo w/ prefetches)', 'metric_L1D demand data read hits per instr',
            'metric_L1-I code read misses (w/ prefetches) per instr', 'metric_L2 demand data read hits per instr',
            'metric_L2 MPI (includes code+data+rfo w/ prefetches)', 'metric_L2 demand data read MPI',
            'metric_L2 demand code MPI', 'metric_L2 Any local request that HITM in a sibling core (per instr)',
            'metric_L2 Any local request that HIT in a sibling core and forwarded(per instr)',
            'metric_L2 % of all lines evicted that are unused prefetches',
            'metric_L2 % of L2 evictions that are allocated into L3',
            'metric_L2 % of L2 evictions that are NOT allocated into L3',
            'metric_LLC code references per instr (L3 prefetch excluded)',
            'metric_LLC data read references per instr (L3 prefetch excluded)',
            'metric_LLC RFO references per instr (L3 prefetch excluded)',
            'metric_LLC MPI (includes code+data+rfo w/ prefetches)', 'metric_LLC data read MPI (demand+prefetch)',
            'metric_LLC RFO read MPI (demand+prefetch)', 'metric_LLC code read MPI (demand+prefetch)',
            'metric_LLC total HITM (per instr) (excludes LLC prefetches)',
            'metric_LLC total HIT clean line forwards (per instr) (excludes LLC prefetches)',
            'metric_Average LLC data read (demand+prefetch) miss latency (in UNCORE clk)',
            'metric_Average LLC data read (demand+prefetch) miss latency  for LOCAL requests (in UNCORE clk)',
            'metric_Average LLC data read (demand+prefetch) miss latency  for REMOTE requests (in UNCORE clk)',
            'metric_LLC Local code/data reads hitting in S state in snoop filter per instr',
            'metric_LLC Local code/data reads hitting in E state in snoop filter per instr',
            'metric_LLC Local code/data reads hitting in S state in LLC per instr',
            'metric_LLC Local code/data reads hitting in M/E/F states in LLC per instr',
            'metric_LLC Remote snoops hitting in S state in snoop filter per instr',
            'metric_LLC Remote snoops hitting in E state in snoop filter per instr',
            'metric_LLC Remote snoops hitting in S state in LLC per instr', 'metric_ITLB MPI',
            'metric_ITLB large page MPI', 'metric_DTLB load MPI', 'metric_DTLB large page load MPI',
            'metric_DTLB store MPI', 'metric_DTLB load miss latency (in core clks)',
            'metric_DTLB store miss latency (in core clks)', 'metric_ITLB miss latency (in core clks)',
            'metric_NUMA %_Reads addressed to local DRAM', 'metric_NUMA %_Reads addressed to remote DRAM',
            'metric_UPI Data transmit BW (MB/sec) (only data)', 'metric_UPI Transmit utilization_% (includes control)',
            'metric_UPI % cycles transmit link is half-width (L0p)', 'metric_UPI % cycles receive link is half-width (L0p)',
            'metric_HA - Reads vs. all requests', 'metric_HA - Writes vs. all requests', 'metric_HA % of all reads that are local',
            'metric_HA % of all writes that are local', 'metric_HA conflict responses per instr',
            'metric_HA directory lookups that spawned a snoop (per instr)',
            'metric_HA directory lookups that did not spawn a snoop (per instr)', 'metric_M2M directory updates (per instr)',
            'metric_M2M extra reads from XPT-UPI prefetches (per instr)', 'metric_memory bandwidth read (MB/sec)',
            'metric_memory bandwidth write (MB/sec)', 'metric_memory bandwidth total (MB/sec)',
            'metric_memory extra read b/w due to XPT prefetches (MB/sec)',
            'metric_memory extra write b/w due to directory updates (MB/sec)',
            'metric_memory average number of entries in each read Q (RPQ)',
            'metric_memory average number of entries in each write Q (WPQ)', 'metric_3DXP_memory bandwidth read (MB/sec)',
            'metric_3DXP_memory bandwidth write (MB/sec)', 'metric_3DXP_memory bandwidth total (MB/sec)',
            'metric_IO_bandwidth_disk_or_network_writes (MB/sec)', 'metric_IO_bandwidth_disk_or_network_reads (MB/sec)',
            'metric_IO_number of partial PCI writes per sec', 'metric_IO_write cache miss(disk/network reads) bandwidth (MB/sec)',
            'metric_IO_read cache miss(disk/network writes) bandwidth (MB/sec)', 'metric_MMIO reads per instr',
            'metric_MMIO writes per instr', 'metric_memory reads vs. all requests', 'metric_memory Page Empty vs. all requests',
            'metric_memory Page Misses vs. all requests', 'metric_memory Page Hits vs. all requests',
            'metric_memory % Cycles where all DRAM ranks are in PPD mode',
            'metric_memory % Cycles all ranks in critical thermal throttle',
            'metric_memory % Cycles Memory is in self refresh power mode',
            'metric_ItoM operations (fast strings) that reference LLC per instr',
            'metric_ItoM operations (fast strings) that miss LLC per instr', 'metric_% Uops delivered from decoded Icache (DSB)',
            'metric_% Uops delivered from legacy decode pipeline (MITE)', 'metric_% Uops delivered from microcode sequencer (MS)',
            'metric_% Uops delivered from loop stream detector (LSD)',
            'metric_FP scalar single-precision FP instructions retired per instr',
            'metric_FP scalar double-precision FP instructions retired per instr',
            'metric_FP 128-bit packed single-precision FP instructions retired per instr',
            'metric_FP 128-bit packed double-precision FP instructions retired per instr',
            'metric_FP 256-bit packed single-precision FP instructions retired per instr',
            'metric_FP 256-bit packed double-precision FP instructions retired per instr',
            'metric_FP 512-bit packed single-precision FP instructions retired per instr',
            'metric_FP 512-bit packed double-precision FP instructions retired per instr', 'metric_DRAM power (watts)',
            'metric_package power (watts)', 'metric_core c3 residency %', 'metric_core c6 residency %', 'metric_package c2 residency %',
            'metric_package c3 residency %', 'metric_package c6 residency %', 'metric_TMAM_Info_CoreIPC',
            'metric_TMAM_Info_Memory Level Parallelism', 'metric_TMAM_Info_cycles_both_threads_active(%)',
            'metric_TMAM_Frontend_Bound(%)', 'metric_TMAM_..Frontend_Latency(%)', 'metric_TMAM_....ICache_Misses(%)',
            'metric_TMAM_....ITLB_Misses(%)', 'metric_TMAM_....Branch_Resteers(%)', 'metric_TMAM_....DSB_Switches(%)',
            'metric_TMAM_....MS_Switches(%)', 'metric_TMAM_..Frontend_Bandwidth(%)', 'metric_TMAM_Bad_Speculation(%)',
            'metric_TMAM_..Branch_Mispredicts(%)', 'metric_TMAM_..Machine_Clears(%)', 'metric_TMAM_Backend_bound(%)',
            'metric_TMAM_..Memory_Bound(%)', 'metric_TMAM_....L1_Bound(%)', 'metric_TMAM_......DTLB_Load(%)',
            'metric_TMAM_......Store_Fwd_Blk(%)', 'metric_TMAM_......Lock_Latency(%)', 'metric_TMAM_....L2_Bound(%)',
            'metric_TMAM_....L3_Bound(%)', 'metric_TMAM_......Contested_Accesses(%)', 'metric_TMAM_......Data_Sharing(%)',
            'metric_TMAM_......L3_Latency(%)', 'metric_TMAM_......L3_Bandwidth(%)', 'metric_TMAM_......SQ_Full(%)',
            'metric_TMAM_....MEM_Bound(%)', 'metric_TMAM_......MEM_Bandwidth(%)', 'metric_TMAM_......MEM_Latency(%)',
            'metric_TMAM_....Stores_Bound(%)', 'metric_TMAM_......DTLB_Store(%)', 'metric_TMAM_..Core_Bound(%)',
            'metric_TMAM_....Divider(%)', 'metric_TMAM_....Ports_Utilization(%)', 'metric_TMAM_......0_Ports_Utilized(%)',
            'metric_TMAM_......1_Port_Utilized(%)', 'metric_TMAM_......2_Ports_Utilized(%)', 'metric_TMAM_......3m_Ports_Utilized(%)',
            'metric_TMAM_Retiring(%)', 'metric_TMAM_..Base(%)', 'metric_TMAM_....FP_Arith(%)', 'metric_TMAM_....Other(%)',
            'metric_TMAM_..Microcode_Sequencer(%)', 'metric_GFLOPS/s.SCALAR_SINGLE', 'metric_GFLOPS/s.SCALAR_DOUBLE',
            'metric_GFLOPS/s.128B_PACKED_DOUBLE', 'metric_GFLOPS/s.128B_PACKED_SINGLE', 'metric_GFLOPS/s.256B_PACKED_SINGLE',
            'metric_GFLOPS/s.256B_PACKED_DOUBLE', 'metric_GFLOPS/s.512B_PACKED_SINGLE', 'metric_GFLOPS/s.512B_PACKED_DOUBLE',
            'metric_FLOPS.SCALAR_SINGLE(%)', 'metric_FLOPS.SCALAR_DOUBLE(%)', 'metric_FLOPS.128B_PACKED_DOUBLE(%)',
            'metric_FLOPS.128B_PACKED_SINGLE(%)']

max_cols = ['timestamp', 'unix_Timestamp', 'system.tsc_freq', 'system.sockets[1][0].size',
            'system.sockets[1].cores.count', 'system.sockets[0][0].size', 'system.sockets[0].cores.count',
            'system.sockets.count', 'number_of_online_processors', 'suggested_start', 'suggested_stop',
            'interval', 'suggested_start_confidence', 'suggested_stop_confidence', 'raw_emon', 'dram_channels',
            'performance', 'run', 'workload', 'instances', 'cores per instance', 'cores used', 'core freq',
            'uncore freq', 'DRAM freq', 'metrics', 'node', 'cpu_family', 'cpu_short', 'namespace', 'agg_secs']


# everything else will be 'summed' to new granularity

# %%
def aggregate(entry):
    workload = entry['name']
    new_granularity_sec = entry['agg_secs']
    dir = entry['emon_dir']
    file = dir + "/" + workload + "_emon_sum.csv"
    filename = dir + "/%s_emon_%.3fsec.csv"%(workload, new_granularity_sec)
    start_time = time.time()
    
    if os.path.isfile(filename):
        if OVERWRITE == False:
            return
        else:
            os.remove(filename)
    log("info", "Aggregating %s..."%(workload))

    if not os.path.isfile(file):
        log("warning", "Can't find %s to aggregate"%(file))
        if os.path.isfile(filename):
            os.remove(filename)
        return
    
    # read in csv, create temp df
    csv = pd.read_csv(file, index_col=0)
    new_dict = {}
    df_sum = pd.DataFrame(columns=csv.columns)
    df_max = pd.DataFrame(columns=csv.columns)
    df_avg = pd.DataFrame(columns=csv.columns)
    df = pd.DataFrame(columns=csv.columns)

    # check if need to aggregate
    current_granularity_sec = float('%.3f'%(csv['duration'].mean()))
    current_stddev_sec = float('%.3f'%(csv['duration'].std()))
    if current_granularity_sec > new_granularity_sec or \
        new_granularity_sec / current_granularity_sec < 1.1:
        log("warning", "%s current granularity %.3f is already greater than or close enough to %.3f"%(workload, current_granularity_sec, new_granularity_sec))
        csv.to_csv(filename)
        return
    if current_stddev_sec >= (current_granularity_sec / 2.0):
        log("error", "%s interval duration %.3f std dev is too large @ %.3f, might be a bad run"%(workload, current_granularity_sec, current_stddev_sec))
        if os.path.isfile(filename):
            os.remove(filename)
        return
    
    intervals_to_combine = round(new_granularity_sec / current_granularity_sec)
    
    if intervals_to_combine > len(csv):
        log("error", "%s interval count %d less than required %d"%(workload, len(csv), intervals_to_combine))
        if os.path.isfile(filename):
            os.remove(filename)
        return

    # calculate avg, max, sum based on column and aggregate (uses dict instead of df for speed)
    new_interval = 0
    for i in range(0, len(csv.index), intervals_to_combine):
        new_dict[new_interval] = {}
        for label in list(csv):
            if label in max_cols:
                new_dict[new_interval][label] = csv.iloc[i:i+intervals_to_combine][label].max()
            elif label in avg_cols:
                new_dict[new_interval][label] = csv.iloc[i:i+intervals_to_combine][label].mean()
            else:
                if is_numeric_dtype(csv[label]):  # sum
                    new_dict[new_interval][label] = csv.iloc[i:i+intervals_to_combine][label].mean() * (new_granularity_sec / current_granularity_sec)
                else:  # max
                    new_dict[new_interval][label] = csv.iloc[i:i+intervals_to_combine][label].max()
        new_interval += 1
    df = pd.DataFrame.from_dict(new_dict, "index")
            
    # reset interval numbers
    df['interval'] = df.index
    
    # fix suggested start & stop intervals due to aggregation
    df['suggested_start'] = df['suggested_start'].map(lambda x: math.floor(x / intervals_to_combine) if x is not None else x)
    df['suggested_stop'] = df['suggested_stop'].map(lambda x: math.floor(x / intervals_to_combine) if x is not None else x)
            
    #print(df)
    df.to_csv(filename)

    log("info", "Aggregated %s in %d secs, combining %d intervals for %.3f -> %.3f sec"%(
        workload, time.time() - start_time, intervals_to_combine, current_granularity_sec, new_granularity_sec))

# %% [markdown]
# # # ADD XML METRICS

# %%
def isfloat(num):
    try:
        a = float(num)
        return not math.isnan(a)
    except ValueError:
        return False


def get_raw_data(file_name, phase_start_stamp, phase_stop_stamp):  
    raw_data = pd.read_csv(open(file_name, 'rb'), index_col=0)

    if phase_start_stamp is not None and phase_stop_stamp is not None:
        raw_data = raw_data[raw_data['unix_Timestamp'].map(lambda x: x > phase_start_stamp and x < phase_stop_stamp)]
    
    #if DEBUG:
    #    print("\tStart raw data")
    #    print("\t",str(raw_data.iloc[:2,0:2]))
    #    print("\tStop raw data")
    #    print("\t",str(raw_data.iloc[-2:,0:2]))
    #    print()

    return raw_data


def get_python_formula(formula):

    # Replace '?' with python ternary operator
    while '?' in formula:

        # m = re.search(r'([^\?]+)\?([^:]+):(.*)', formula)
        # Above formula does not support nesting
        # Using (.*) for the first group leads looking for
        # innermost ternary operator
        m = re.search(r'(.*)\?([^:]+):(.*)', formula)

        # Condition
        paran_stack = []
        paran_matches = list(re.finditer("\(|\)", m.group(1)))
        start_replace = None
        for m1 in reversed(paran_matches):
            if m1.group(0) == ")":
                 paran_stack.append(m1.start())
            else:
                paran_stack.pop()
                if not paran_stack:
                    condition = m.group(1)[m1.start():]
                    start_replace = m.start(1) + m1.start()
                    break

        # True part
        true_part = m.group(2)

        # False part
        paran_matches = list(re.finditer("\(|\)", m.group(3)))
        end_replace = None
        for m1 in reversed(paran_matches):
            if m1.group(0) == ")":
                 paran_stack.append(m1.start())
            else:
                 paran_stack.pop()
        if paran_stack:
            end_replace = paran_stack.pop()
            false_part = m.group(3)[:end_replace]
            end_replace += m.start(3)

        if end_replace is None or start_replace is None:
            log("error", "Error in formula evaluation")
            return None

        formula = formula[:start_replace] + "(" + true_part + ") if (" + condition + ") else (" + false_part + ")" + formula[end_replace:]

        #print("C:" + condition)
        #print("true_part:" + true_part)
        #print("false_part:" + false_part)
        #print(formula)

    # Replace '.min' directives with python compatible ones
    while '.min' in formula:

        m = re.search(r'(\.min)', formula)
        ss = formula[0:m.start(1)]
        bracket_matches = list(re.finditer("\[|\]", ss))
        replace_end = m.start(1) + 4
        bracket_stack = []
        for m1 in reversed(bracket_matches):
            if m1.group(0) == "]":
                bracket_stack.append(m1.start())
            else:
                bracket_stack.pop()
                if not bracket_stack:
                    ss1 = ss[m1.start()+1:-1]
                    replace_start = m.start(1) + m1.start()
                    break

        formula = formula[:m1.start()] + "min(" + ss1 + ")" + formula[replace_end:]

    return formula
    

# handles if there is a divide by zero in an equation
def eval_row(formula, row):
    try:
        return eval(formula)
    except Exception:
        return None
    
    
def evaluate_metrics_row(raw_data, metrics_definition_path, out_file):
    if raw_data is None:
        return None
    
    # read in xml and copy raw emon data
    tree = ET.parse(metrics_definition_path)
    root = tree.getroot()
    new_data = copy.deepcopy(raw_data)

    for child in root:
        if DEBUG:
            print("\t", child.attrib['name'])
        
        # get formula
        all_counters = True
        formula = ""
        for grandchild in child:
            if grandchild.tag == 'formula' and 'socket' not in grandchild.keys():
                formula = get_python_formula(grandchild.text)
                #print(formula)  # original formula with aliases
                break
                     
        # replace alias' with dataframe rows to evaluate
        for grandchild in child:
            if grandchild.tag == 'event':
                if grandchild.text not in list(raw_data):
                    if DEBUG:
                        log("warning", "Continuing..." + grandchild.text + " not found")
                    all_counters = False
                    break
                else:
                    # the regex character '\b' is a word boundary, so it will only replace an alias surrounded by non-letters
                    # this covers the case where you want to replace an alias 'a' but there is also the word 'threads' in the formula
                    formula = re.sub(r'\b' + grandchild.attrib['alias'] + r'\b', "row['" + grandchild.text + "']", formula)
            elif grandchild.tag == 'constant':
                try:
                    float(grandchild.text)
                    formula = re.sub(r'\b' + grandchild.attrib['alias'] + r'\b', grandchild.text, formula)
                except Exception:
                    if grandchild.text not in list(raw_data):
                        if DEBUG:
                            log("warning", "Continuing..." + grandchild.text + " not found")
                        all_counters = False
                        break
                    else:
                        formula = re.sub(r'\b' + grandchild.attrib['alias'] + r'\b', "row['" + grandchild.text + "']", formula)

        if not all_counters:
            new_data[child.attrib['name']] = None
        else:
            try:
                new_data[child.attrib['name']] = new_data.apply(lambda row: eval_row(formula, row), axis=1)
            except:
                log("warning", "Problem in formula evaluation: " + child.attrib['name'] + \
                    "\nFormula: " + formula) # new formula with column names
                return

    #new_data.to_csv(out_file)
    return new_data

# %%
metric_dir = "/mnt/san03RAID1/tools/AIBench/EMON_event_files/"
metrics_files = {
    'skx': metric_dir + 'SKX-2S/skx-2s.xml',
    'bdx': metric_dir + 'BDX-EP/bdx-ep_w_FLOPS_fixed.xml',
    'clx': metric_dir + 'Architecture Specific/CascadeLake/CLX-2S/clx-2s.xml',
    'amd': metric_dir + 'Architecture Specific/Competitive/AMD/zen.xml',
}

def get_FMA_mult(row):
    if 'cpu_short' in row:
        if row['cpu_short'] == 'skx':
            return (8*2*2) * 2
        elif row['cpu_short'] == 'clx':
            return (8*2*2) * 2
        elif row['cpu_short'] == 'bdx':
            return (4*2*2) * 2
        else: # same as SKX
            return (8*2*2) * 2
    
    else:  # assume SKX
        return (8*2*2) * 2

def calculate_metrics(entry):
    #print("Calculating XML Metrics...")
    run = entry['name']
    dir = entry['emon_dir']
    new_granularity_sec = entry['agg_secs']
    file = dir + "/" + run + "_emon_%.3fsec.csv"%(new_granularity_sec)
    output_file = dir + "/" + run + "_emon_%.3fsec_metrics.csv"%(new_granularity_sec)
    start_stamp = None
    stop_stamp = None
    start_time = time.time()
    
    #max_upi = 10.4 * 12 * 8  # GB/s, NEEDS TO BE CONFIRMED
    
    if os.path.isfile(output_file):
        if OVERWRITE == False:
            return
        else:
            os.remove(output_file)
    
    if not os.path.isfile(file):
        log("warning,", "Can't find %s to add metrics"%(file))
        if os.path.isfile(output_file):
            os.remove(output_file)
        return
    
    try:
        raw_data = get_raw_data(file, start_stamp, stop_stamp)
        if 'cpu_short' in raw_data:
            cpu_short = raw_data['cpu_short'].values[0]
            if cpu_short == 'skx':
                if 'UNC_CHA_CLOCKTICKS' in raw_data:
                    raw_data['metrics_file'] = metric_dir + 'SKX-2S/skx-2s_cha.xml'
                else:
                    raw_data['metrics_file'] = metric_dir + 'SKX-2S/' + entry['metrics']
            elif cpu_short == 'bdx' or cpu_short == 'clx' or cpu_short == 'amd':
                raw_data['metrics_file'] = metrics_files[cpu_short]
            else:
                log("warning", "cpu_family for %s is %s, not adding metrics!"%(run, cpu_short))
                raw_data.to_csv(output_file)
                return
        else:
            log("warning", "Can't determine cpu family for %s, assuming SKX!"%(run))
            raw_data['cpu_short'] = 'skx'
            raw_data['metrics_file'] = metric_dir + 'SKX-2S/' + entry['metrics']
        
        metric_file = raw_data['metrics_file'].values[0]
        print("Using metric file %s"%(metric_file))
        log("info", "Calculating metrics for %s using %s..."%(run, metric_file))
        new_data = evaluate_metrics_row(raw_data, metric_file, output_file)
    except Exception as e:
        log("error", "Exception for %s: %s: %s"%(run, sys.exc_info()[0], e))
        return
    
    #add some extra non-xml metrics
    pcie_3_x8_max_bw = 7.88e9  # B/s
    new_data['cum_duration'] = new_data['duration'].cumsum()
    new_data['cores available'] = new_data['system.sockets[0].cores.count'] + new_data['system.sockets[1].cores.count']
    if cpu_short == 'amd':
        new_data['NUMA %local'] = new_data['metric_NUMA %_Reads addressed to local DRAM/Die'] / \
                                   (new_data['metric_NUMA %_Reads addressed to local DRAM/Die'] + \
                                    new_data['metric_NUMA %_Reads addressed to remote DRAM/Die'])
        new_data['L3 MPKI'] = new_data['metric_L3 misses per instr'] * 1000
        new_data['L2 MPKI'] = new_data['metric_L2 Demand Read (dataRd+rfo) MPI '] * 1000
        new_data['metric_memory bandwidth read (MB/sec)'] = 0
        new_data['metric_memory bandwidth write (MB/sec)'] = 0
        new_data['DDR BW/core (GB/s)'] = (new_data['metric_memory bandwidth read (MB/sec)'] + new_data['metric_memory bandwidth write (MB/sec)']) / new_data['cores used'] / 1000
        new_data['Remote hitm (%LLC miss)'] = 0
        new_data['DDR Rd Ratio'] = new_data['metric_memory bandwidth read (MB/sec)'] / new_data['metric_memory bandwidth write (MB/sec)']
        new_data['IO BW (MB/s)'] = 0
        new_data['PCIE 3.0 x8 Util'] = 0
        new_data['CPU Utilization used threads %'] = new_data.apply(lambda row: min(100.0, row['metric_CPU utilization %'] * (row['cores available'] * 2 / row['cores used'])), axis=1)
        new_data['metric_UPI Transmit utilization_% (includes control)'] = 0
        new_data['metric_TMAM_Frontend_Bound(%)'] = 0
        new_data['metric_TMAM_Backend_bound(%)'] = 0
        new_data['metric_TMAM_Bad_Speculation(%)'] = 0
        new_data['metric_TMAM_Retiring(%)'] = 0
        new_data['Roofline Elbow'] = 0
        new_data['Theoretical Peak GFLOPS/s'] = 0
        new_data['metric_GFLOPS/s'] = 0
        new_data['metric_Arithmetic Intensity'] = 0
    else:
        new_data['DRAM Bytes'] = (new_data['UNC_M_CAS_COUNT.RD'] + new_data['UNC_M_CAS_COUNT.WR']) * 64.0
        new_data['DDR BW/core (GB/s)'] = (new_data['metric_memory bandwidth read (MB/sec)'] + new_data['metric_memory bandwidth write (MB/sec)']) / new_data['cores used'] / 1000
        new_data['DDR Rd Ratio'] = new_data['metric_memory bandwidth read (MB/sec)'] / new_data['metric_memory bandwidth write (MB/sec)']
        new_data['CPU Utilization used threads %'] = new_data.apply(lambda row: min(100.0, row['metric_CPU utilization %'] * (row['cores available'] * 2 / row['cores used'])), axis=1)
        new_data['Theoretical Peak DRAM GB/s'] = new_data['DRAM freq'] * 8 * new_data['dram_channels'] / 1000
        try:
            new_data['Theoretical Peak GFLOPS/s'] = new_data.apply(lambda row: (min(row['cores available'], row['cores used']) * pd.to_numeric(row['core freq']) * get_FMA_mult(row)), axis=1)
        except Exception:
            new_data['Theoretical Peak GFLOPS/s'] = new_data.apply(lambda row: (min(row['cores available'], row['cores used']) * row['system.tsc_freq'] / 1e9 * get_FMA_mult(row)), axis=1)
        new_data['Roofline Elbow'] = new_data['Theoretical Peak GFLOPS/s'] / new_data['Theoretical Peak DRAM GB/s']
        
        if 'memory' not in entry['metrics']:  # flops or default or proxy
            new_data['GFLOPS/s/core'] = new_data['metric_GFLOPS/s'] / new_data['cores used']
            new_data['FP Utilization %'] = new_data['metric_GFLOPS/s'] / new_data['Theoretical Peak GFLOPS/s'] * 100.0
            new_data['Achievable Peak GFLOPS/s'] = new_data.apply(lambda row: min(row['Theoretical Peak GFLOPS/s'], row['Theoretical Peak DRAM GB/s'] * row['metric_Arithmetic Intensity']), axis=1)
            new_data['FP Efficiency %'] = new_data['metric_GFLOPS/s'] / new_data['Achievable Peak GFLOPS/s'] * 100.0
            if 'flops' not in entry['metrics']:  # default or proxy
                new_data['NUMA %local'] = new_data['metric_NUMA %_Reads addressed to local DRAM'] / \
                                         (new_data['metric_NUMA %_Reads addressed to local DRAM'] + \
                                          new_data['metric_NUMA %_Reads addressed to remote DRAM'])
                new_data['IO BW (MB/s)'] = (new_data['metric_IO_bandwidth_disk_or_network_writes (MB/sec)'] + new_data['metric_IO_bandwidth_disk_or_network_reads (MB/sec)'])
                new_data['PCIE 3.0 x8 Util %'] = new_data['IO BW (MB/s)'] * 1e6 / pcie_3_x8_max_bw * 100
                if cpu_short == 'bdx':
                    new_data['L3 MPKI'] = new_data['MEM_LOAD_UOPS_RETIRED.L3_MISS'] / new_data['INST_RETIRED.ANY'] * 1000
                    new_data['L2 MPKI'] = new_data['MEM_LOAD_UOPS_RETIRED.L2_MISS'] / new_data['INST_RETIRED.ANY'] * 1000
                    new_data['Remote hitm (%LLC miss)'] = new_data['OFFCORE_RESPONSE:request=ALL_READS:response=LLC_MISS.REMOTE_HITM'] / \
                                                         (new_data['OFFCORE_RESPONSE:request=ALL_READS:response=LLC_MISS.REMOTE_HITM'] + \
                                                          new_data['MEM_LOAD_UOPS_RETIRED.L3_MISS'])
                else:
                    new_data['L3 MPKI'] = new_data['MEM_LOAD_RETIRED.L3_MISS'] / new_data['INST_RETIRED.ANY'] * 1000
                    new_data['L2 MPKI'] = new_data['MEM_LOAD_RETIRED.L2_MISS'] / new_data['INST_RETIRED.ANY'] * 1000
                    new_data['Remote hitm (%LLC miss)'] = new_data['OFFCORE_RESPONSE:request=ALL_READS:response=L3_MISS.REMOTE_HITM'] / \
                                                         (new_data['OFFCORE_RESPONSE:request=ALL_READS:response=L3_MISS.REMOTE_HITM'] + \
                                                          new_data['MEM_LOAD_RETIRED.L3_MISS'])
                if 'proxy' not in entry['metrics']:  # default
                    new_data['IO BW cache miss (MB/s)'] = (new_data['metric_IO_write cache miss(disk/network reads) bandwidth (MB/sec)'] + new_data['metric_IO_read cache miss(disk/network writes) bandwidth (MB/sec)'])
                    #new_data['metric_Average LLC data read (demand+prefetch) miss latency (in ns)'] = new_data['metric_Average LLC data read (demand+prefetch) miss latency (in UNCORE clk)'] / ((new_data['UNC_C_CLOCKTICKS'] / new_data['cores available']) / new_data['duration']) * 1e9
                    #new_data['metric_Average LLC data read (demand+prefetch) miss latency for LOCAL requests (in ns)'] = new_data['metric_Average LLC data read (demand+prefetch) miss latency  for LOCAL requests (in UNCORE clk)'] / ((new_data['UNC_C_CLOCKTICKS'] / new_data['cores available']) / new_data['duration']) * 1e9
                    #new_data['metric_Average LLC data read (demand+prefetch) miss latency for REMOTE requests (in ns)'] = new_data['metric_Average LLC data read (demand+prefetch) miss latency  for REMOTE requests (in UNCORE clk)'] / ((new_data['UNC_C_CLOCKTICKS'] / new_data['cores available']) / new_data['duration']) * 1e9
                    new_data['BACPI'] = new_data['BACLEARS.ANY'] / new_data['INST_RETIRED.ANY']
                    new_data['ABRPI'] = new_data['BR_INST_RETIRED.ALL_BRANCHES'] / new_data['INST_RETIRED.ANY']
                    new_data['JECPI'] = new_data['BR_MISP_RETIRED.ALL_BRANCHES'] / new_data['INST_RETIRED.ANY']
                    if cpu_short == 'bdx':
                        new_data['DIVIDERPI'] = new_data['ARITH.FPU_DIV_ACTIVE'] / new_data['INST_RETIRED.ANY']
                    else:
                        new_data['DIVIDERPI'] = new_data['ARITH.DIVIDER_ACTIVE'] / new_data['INST_RETIRED.ANY']
        

    #save to file
    new_data.to_csv(output_file)

    log("info", "Calculated metrics for %s in %d secs"%(run, time.time() - start_time))

# %% [markdown]
# ## # Create Excel

# %%
bb_columns = [
    'metric_CPI', 'metric_L1D demand data read hits per instr', 'metric_L2 demand data read hits per instr',
    'metric_L2 demand data read MPI', 'metric_ITLB MPI', 'metric_DTLB load MPI', 'metric_DTLB store MPI',
    'DIVIDERPI', 'BACPI', 'ABRPI', 'JECPI',
    'metric_LLC MPI (includes code+data+rfo w/ prefetches)',
    'metric_Average LLC data read (demand+prefetch) miss latency (in ns)',
    'metric_CPU operating frequency (in GHz)',
]
proxy_columns = [
    'metric_CPI', 'NUMA %local', 'L3 MPKI', 'L2 MPKI', 'DDR BW/core (GB/s)', 'Remote hitm (%LLC miss)',
    'DDR Rd Ratio', 'IO BW (MB/s)', 'CPU Utilization used threads %',
    'metric_UPI Transmit utilization_% (includes control)', 'metric_memory bandwidth utilization %',
    'metric_TMAM_Frontend_Bound(%)', 'metric_TMAM_Backend_bound(%)', 'metric_TMAM_Bad_Speculation(%)',
    'metric_TMAM_Retiring(%)', 'metric_Arithmetic Intensity', 'FP Utilization %', 'FP Efficiency %',
]
proxy_rename = [
    'CPI', 'NUMA %local', 'L3 MPKI', 'L2 MPKI', 'DRAM GB/s per core', '%LLC miss',
    'DDR Rd/Wr', 'IO MB/s', 'CPU Util', 'UPI Util', 'DRAM BW Util', 'Frontend Bound',
    'Backend Bound', 'Bad Spec', 'Retiring', 'Intensity', 'FP Util', 'FP Eff',
]

def create_excel(entry):
    run = entry['name']
    dir = entry['emon_dir']
    metrics = entry['metrics']
    new_granularity_sec = entry['agg_secs']
    infile = dir + "/%s_emon_%.3fsec_metrics.csv"%(run, new_granularity_sec)
    outfile = dir + "/%s_emon_%.3fsec_metrics.xlsx"%(run, new_granularity_sec)
    start_time = time.time()
    
    if os.path.isfile(outfile):
        if OVERWRITE == False:
            return
        else:
            os.remove(outfile)
    log("info", "Creating Excel for %s..."%(run))
    
    if not os.path.isfile(infile):
        log("warning", "Can't find %s to create excel"%(infile))
        if os.path.isfile(outfile):
            os.remove(outfile)
        return
    
    #read in input csv
    df = pd.read_csv(infile, index_col=0)
    first_row = 1
    last_row = len(df.index)
    start_row = df['suggested_start'].values[0] + first_row
    end_row = df['suggested_stop'].values[0] + first_row
    
    #create xlsx writer and save EMON data
    writer = pd.ExcelWriter(outfile, engine='xlsxwriter')
    df.to_excel(writer, sheet_name='EMON')
    workbook = writer.book
    
    #create bounding box summary tab
    if set(bb_columns).issubset(df.columns):
        bb_df = df.loc[df['suggested_start'].values[0]:df['suggested_stop'].values[0]][bb_columns].mean()
        bb_df = bb_df.transpose()
        bb_df.to_excel(writer, sheet_name='Bounding Box')

    # create proxy metrics summary tab
    if not set(proxy_columns).issubset(df.columns):
        for column in proxy_columns:
            if column not in df:
                df[column] = None
    proxy_df = df.loc[df['suggested_start'].values[0]:df['suggested_stop'].values[0]][proxy_columns]
    proxy_df.columns = proxy_rename
    proxy_df = proxy_df.mean()
    proxy_df = proxy_df.transpose()
    proxy_df.to_excel(writer, sheet_name='Proxy Metrics')
    
    # create general chart(s)
    workbook.add_worksheet('Charts')
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='scatter',
        chart_subtype='smooth',
        start_row=first_row,
        end_row=last_row,
        x_col_name='cum_duration',
        y_col_names=['INST_RETIRED.ANY'],
        series_names=['Instructions Retired'],
        title='Instructions Retired & Suggested Filter',
        x_label='Time (s)',
        y_label='Instructions Retired',
        y_min=0,
        additional_series=[
            {
                'name':       'Start',
                'categories': [df.loc[df['suggested_start'].values[0]]['cum_duration'], df.loc[df['suggested_start'].values[0]]['cum_duration']],
                'values':     [0, df['INST_RETIRED.ANY'].max()],
                'line':       {'color': 'green'},
                'marker':     {'type': 'none'},
            },
            {
                'name':       'Stop',
                'categories': [df.loc[df['suggested_stop'].values[0]]['cum_duration'], df.loc[df['suggested_stop'].values[0]]['cum_duration']],
                'values':     [0, df['INST_RETIRED.ANY'].max()],
                'line':       {'color': 'red'},
                'marker':     {'type': 'none'},
            },
        ]
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='scatter',
        chart_subtype='smooth',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=['metric_CPU utilization %','CPU Utilization used threads %'],
        series_names=['CPU utilization % all threads','CPU Utilization % used threads'],
        title='CPU Utilization over Time',
        x_label='Time (s)',
        y_label='CPU Util (%)',
        y_min=0,
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='scatter',
        chart_subtype='smooth',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=['metric_memory bandwidth utilization %'],
        series_names=['DRAM BW Utilization %'],
        title='DRAM BW Utilization over Time',
        x_label='Time (s)',
        y_label='DRAM BW Util (%)',
        disable_legend=True,
        y_min=0,
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='scatter',
        chart_subtype='smooth',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=['metric_Average LLC data read (demand+prefetch) miss latency (in ns)'],
        series_names=['DRAM Read Latency'],
        title='DRAM Latency over Time',
        x_label='Time (s)',
        y_label='DRAM Read Latency (ns)',
        disable_legend=True,
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='scatter',
        chart_subtype='smooth',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=['DDR Rd Ratio'],
        title='DRAM RD/WR Ratio over Time',
        x_label='Time (s)',
        y_label='DRAM RD/WR',
        disable_legend=True,
        y_min=0,
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='scatter',
        chart_subtype='smooth',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=['metric_CPI'],
        series_names=['CPI'],
        title='CPI over Time',
        x_label='Time (s)',
        y_label='CPI',
        disable_legend=True,
        y_min=0,
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='scatter',
        chart_subtype='smooth',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=['L3 MPKI', 'L2 MPKI'],
        title='MPKI over Time',
        x_label='Time (s)',
        y_label='MPKI',
        y_min=0,
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='scatter',
        chart_subtype='smooth',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_IO_bandwidth_disk_or_network_writes (MB/sec)',
            'metric_IO_bandwidth_disk_or_network_reads (MB/sec)',
        ],
        series_names=['IO BW disk or network Writes','IO BW disk or network Reads'],
        title='IO Bandwidth over Time',
        x_label='Time (s)',
        y_label='IO BW (MB/s)',
        y_min=0,
    )
    if 'metric_Arithmetic Intensity' in df:
        add_chart(
            workbook=workbook,
            chartsheet='Charts',
            datasheet='EMON',
            df=df,
            chart_type='scatter',
            start_row=start_row,
            end_row=end_row,
            x_col_name='metric_Arithmetic Intensity',
            y_col_names=['metric_GFLOPS/s'],
            series_names=['GFLOPS/s'],
            title='Roofline',
            x_label='Arithmetic Intensity',
            y_label='GFLOPS/s',
            disable_legend=True,
            x_log_base=10,
            y_log_base=10,
            x_min=1e-6,
            x_max=1e3,
            y_min=1e-6,
            additional_series=[
                {
                    'name':       'Roofline',
                    'categories': [1e-100, df['Roofline Elbow'].values[0], 1e3],
                    'values':     [1e-100, df['Theoretical Peak GFLOPS/s'].values[0], df['Theoretical Peak GFLOPS/s'].values[0]],
                    'line':       {'color': 'black'},
                    'marker':     {'type': 'none'},
                },
                {
                    'name':       'Average',
                    'categories': [df.loc[df['suggested_start'].values[0]:df['suggested_stop'].values[0]]['metric_Arithmetic Intensity'].mean()],
                    'values':     [df.loc[df['suggested_start'].values[0]:df['suggested_stop'].values[0]]['metric_GFLOPS/s'].mean()],
                    'marker':     {'type': 'circle', 'fill': {'color': 'red'}, 'border': {'color': 'red'}}
                },
            ]
        )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='scatter',
        chart_subtype='smooth',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=['FP Utilization %', 'FP Efficiency %'],
        title='Floating Point Usage',
        x_label='Time (s)',
        y_label='FP (%)',
        y_min=0,
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='area',
        chart_subtype='stacked',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_FLOPS.SCALAR_SINGLE(%)',
            'metric_FLOPS.SCALAR_DOUBLE(%)',
            'metric_FLOPS.128B_PACKED_SINGLE(%)',
            'metric_FLOPS.128B_PACKED_DOUBLE(%)',
            'metric_FLOPS.256B_PACKED_SINGLE(%)',
            'metric_FLOPS.256B_PACKED_DOUBLE(%)',
            'metric_FLOPS.512B_PACKED_SINGLE(%)',
            'metric_FLOPS.512B_PACKED_DOUBLE(%)',
        ],
        series_names=[
            'Scalar Single',
            'Scalar Double',
            '128B Packed Single',
            '128B Packed Double',
            '256B Packed Single',
            '256B Packed Double',
            '512B Packed Single',
            '512B Packed Double',
        ],
        title='Floating Point Breakdown',
        x_label='Time (s)',
        y_label='% FP Mix',
        y_min=0,
        y_max=100,
        num_format='0',
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='area',
        chart_subtype='stacked',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_TMAM_Retiring(%)',
            'metric_TMAM_Frontend_Bound(%)',
            'metric_TMAM_Backend_bound(%)',
            'metric_TMAM_Bad_Speculation(%)',
        ],
        series_names=[
            'Retiring',
            'Frontend Bound',
            'Backend Bound',
            'Bad Speculation',
        ],
        title='TMAM Level 1',
        x_label='Time (s)',
        y_label='% Cycles Spent',
        y_min=0,
        y_max=100,
        num_format='0',
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='area',
        chart_subtype='stacked',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_TMAM_..Base(%)',
            'metric_TMAM_..Microcode_Sequencer(%)',
            'metric_TMAM_..Branch_Mispredicts(%)',
            'metric_TMAM_..Machine_Clears(%)',
            'metric_TMAM_..Frontend_Latency(%)',
            'metric_TMAM_..Frontend_Bandwidth(%)',
            'metric_TMAM_..Core_Bound(%)',
            'metric_TMAM_..Memory_Bound(%)',
        ],
        series_names=[
            'Retiring:Base', 'Retiring:MS-ROM', 'Bad Spec:Branch Mispredict', 'Bad Spec:Machine Clears',
            'Frontend:Latency', 'Frontend:Bandwidth', 'Backend:Core','Backend:Memory'],
        title='TMAM Level 2',
        x_label='Time (s)',
        y_label='% Cycles Spent',
        y_min=0,
        y_max=100,
        num_format='0',
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='area',
        chart_subtype='stacked',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_TMAM_....FP_Arith(%)',
            'metric_TMAM_....Other(%)',
        ],
        series_names=['Retiring:Base:FP-Arith', 'Retiring:Base:Other'],
        title='TMAM Level 3 Retiring:Base',
        x_label='Time (s)',
        y_label='% Cycles Spent',
        num_format='0',
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='area',
        chart_subtype='stacked',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_TMAM_....ITLB_Misses(%)',
            'metric_TMAM_....ICache_Misses(%)',
            'metric_TMAM_....Branch_Resteers(%)',
            'metric_TMAM_....DSB_Switches(%)',
            'metric_TMAM_....MS_Switches(%)',
        ],
        series_names=['Frontend:Latency:ITLB Misses', 'Frontend:Latency:ICache Misses',
                      'Frontend:Latency:Branch Resteers', 'Frontend:Latency:DSB Switches',
                      'Frontend:Latency:MS Switches',
        ],
        title='TMAM Level 3 Frontend:Latency',
        x_label='Time (s)',
        y_label='% Cycles Spent',
        num_format='0',
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='area',
        chart_subtype='stacked',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_TMAM_....Divider(%)',
            'metric_TMAM_....Ports_Utilization(%)',
        ],
        series_names=['Backend:Core:Divider', 'Backend:Core:Port Utilization'],
        title='TMAM Level 3 Backend:Core',
        x_label='Time (s)',
        y_label='% Cycles Spent',
        num_format='0',
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='area',
        chart_subtype='stacked',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_TMAM_....L1_Bound(%)',
            'metric_TMAM_....L2_Bound(%)',
            'metric_TMAM_....L3_Bound(%)',
            'metric_TMAM_....MEM_Bound(%)',
            'metric_TMAM_....Stores_Bound(%)', 
        ],
        series_names=['Backend:Memory:L1', 'Backend:Memory:L2', 'Backend:Memory:L3',
                      'Backend:Memory:Mem', 'Backend:Memory:Stores'],
        title='TMAM Level 3 Backend:Memory',
        x_label='Time (s)',
        y_label='% Cycles Spent',
        num_format='0',
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='area',
        chart_subtype='stacked',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_TMAM_......Mispredicts_Resteers(%)',
            'metric_TMAM_......Clears_Resteers(%)',
            'metric_TMAM_......Unknown_Branches_Resteers(%)',
        ],
        series_names=['Frontend:Latency:Branch Resteers:Mispredicts', 'Frontend:Latency:Branch Resteers:Clears',
                      'Frontend:Latency:Branch Resteers:Unknown'],
        title='TMAM Level 4 Frontend:Latency:Branch Resteers',
        x_label='Time (s)',
        y_label='% Cycles Spent',
        num_format='0',
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='area',
        chart_subtype='stacked',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_TMAM_......DTLB_Load(%)',
            'metric_TMAM_......Store_Fwd_Blk(%)',
            'metric_TMAM_......Lock_Latency(%)',
        ],
        series_names=['Backend:Memory:L1:DTLB Load', 'Backend:Memory:L1:Store Fwd Blk',
                      'Backend:Memory:L1:Lock Latency'],
        title='TMAM Level 4 Backend:Memory:L1',
        x_label='Time (s)',
        y_label='% Cycles Spent',
        num_format='0',
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='area',
        chart_subtype='stacked',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_TMAM_......Contested_Accesses(%)',
            'metric_TMAM_......Data_Sharing(%)',
            'metric_TMAM_......L3_Latency(%)',
            'metric_TMAM_......L3_Bandwidth(%)',
            'metric_TMAM_......SQ_Full(%)',
        ],
        series_names=['Backend:Memory:L3:Contested Accesses', 'Backend:Memory:L3:Data Sharing',
                      'Backend:Memory:L3:Latency', 'Backend:Memory:L3:Bandwidth', 'Backend:Memory:L3:SQ Full'],
        title='TMAM Level 4 Backend:Memory:L3',
        x_label='Time (s)',
        y_label='% Cycles Spent',
        num_format='0',
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='area',
        chart_subtype='stacked',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_TMAM_......MEM_Bandwidth(%)',
            'metric_TMAM_......MEM_Latency(%)',
        ],
        series_names=['Backend:Memory:Mem:Bandwidth', 'Backend:Memory:Mem:Latency'],
        title='TMAM Level 4 Backend:Memory:Mem',
        x_label='Time (s)',
        y_label='% Cycles Spent',
        num_format='0',
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='area',
        chart_subtype='stacked',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_TMAM_......DTLB_Store(%)',
        ],
        series_names=['Backend:Memory:Stores:DTLB'],
        title='TMAM Level 4 Backend:Memory:Stores',
        x_label='Time (s)',
        y_label='% Cycles Spent',
        num_format='0',
    )
    add_chart(
        workbook=workbook,
        chartsheet='Charts',
        datasheet='EMON',
        df=df,
        chart_type='area',
        chart_subtype='stacked',
        start_row=start_row,
        end_row=end_row,
        x_col_name='cum_duration',
        y_col_names=[
            'metric_TMAM_......0_Ports_Utilized(%)',
            'metric_TMAM_......1_Ports_Utilized(%)',
            'metric_TMAM_......2_Ports_Utilized(%)',
            'metric_TMAM_......3m_Ports_Utilized(%)',
        ],
        series_names=['Backend:Core:Port Utilization:0', 'Backend:Core:Port Utilization:1',
                      'Backend:Core:Port Utilization:2', 'Backend:Core:Port Utilization:3+'],
        title='TMAM Level 4 Backend:Core:Port Utilization',
        x_label='Time (s)',
        y_label='% Cycles Spent',
        num_format='0',
    )
    
    
    writer.save()
    
    log("info", "Created Excel for %s in %d secs"%(run, time.time() - start_time))

# %%
# 'cursor' state for where to position chart in worksheet
chart_position_state = {}

def format_core_freq(core_freq):
    try:
        return "{0:.1f}".format(round(core_freq,1))
    except Exception:
        return core_freq

def add_chart(workbook, chartsheet, datasheet, df, chart_type, start_row, end_row, y_col_names, title,
              x_col_name=None, chart_subtype=None, x_label=None, y_label=None, x_log_base=None, y_log_base=None,
              x_min=None, x_max=None, y_min=None, y_max=None, disable_legend=False, additional_series=None,
              num_format='General', series_names=None, gap=None, x_interval_unit=None, y_interval_unit=None,
              x_interval_tick=None, y_interval_tick=None, series_filters=None, trendline=None,
              x_visible=True, y_visible=True, x_scale=2, y_scale=2, chart_position='below'):
    
    if workbook not in chart_position_state:
        chart_position_state[workbook] = {}
    if chartsheet not in chart_position_state[workbook]:
        chart_position_state[workbook][chartsheet] = {
            'chart_col' : 1,
            'chart_row_right' : 1,
            'chart_row_below' : 1,
        }
    
    # check columns exist
    columns = df.columns
    if x_col_name is None:
        x_col = None
        categories = None
    else:
        if not x_col_name in columns:
            #print("x-axis %s is not in columns: %s"%(x_col_name, columns))
            return False
        x_col = columns.get_loc(x_col_name) + 1
        categories = [datasheet, start_row, x_col, end_row, x_col]
    for y_col_name in y_col_names: 
        if not y_col_name in columns:
            #print("y-axis %s is not in columns: %s"%(y_col_name, columns))
            return False
    
    # create chart
    chart_worksheet = workbook.get_worksheet_by_name(chartsheet)
    chart = workbook.add_chart({'type': chart_type, 'subtype': chart_subtype})
    chart.show_blanks_as('span')
    
    # add main series
    for series_idx, y_col_name in enumerate(y_col_names):
        y_col = columns.get_loc(y_col_name) + 1
        if series_names is not None:
            series_name = series_names[series_idx]
        else:
            series_name = y_col_name
        
        if series_filters is None:
            chart.add_series({
                'name':       series_name,
                'categories': categories,
                'values':     [datasheet, start_row, y_col, end_row, y_col],
                'gap':        gap,
                'trendline':  trendline,
            })
        else:
            #find unique combinations, get row/col of each
            filtered_df = filter_df(series_filters, df)
            
            values = '=('
            categories = '=('
            for row in filtered_df['row'].values:
                values += datasheet + '!' + str(xl_rowcol_to_cell(row+1, y_col)) + ','
                categories += datasheet + '!' + str(xl_rowcol_to_cell(row+1, x_col)) + ','
            values = values.rstrip(',') + ')'
            categories = categories.rstrip(',') + ')'
            
            chart.add_series({
                'name':       series_name,
                'categories': categories,
                'values':     values,
                'gap':        gap,
                'trendline':  trendline,
            })
        
    # add additional series formatted by user
    # Could just chart raw values but xlsxwriter prints annoying warning so instead I'll write data to sheet and chart that
    if additional_series is not None:
        cat_count = val_count = 0
        for series in additional_series:
            chart_col = chart_position_state[workbook][chartsheet]['chart_col']
            chart_row = chart_position_state[workbook][chartsheet]['chart_row_below']
            cat_start_cell = xl_rowcol_to_cell(chart_row + cat_count, chart_col)
            val_start_cell = xl_rowcol_to_cell(chart_row + val_count, chart_col + 1)
            cat_count += len(series['categories'])
            val_count += len(series['values'])
            cat_end_cell = xl_rowcol_to_cell(chart_row + cat_count - 1, chart_col)
            val_end_cell = xl_rowcol_to_cell(chart_row + val_count - 1, chart_col + 1)
            chart_worksheet.write_column(cat_start_cell, series['categories'])
            chart_worksheet.write_column(val_start_cell, series['values'])
            series['categories'] = chartsheet + '!' + cat_start_cell + ':' + cat_end_cell
            series['values'] = chartsheet + '!' + val_start_cell + ':' + val_end_cell
            chart.add_series(series)
        
    # title
    chart.set_title({
        'name': title,
        'name_font': {'size': 18},
    })
    
    # legend
    chart.set_legend({
        'font': {'size': 12},
        'position': 'top',
        'none': disable_legend,
    })
    
    # axis
    chart.set_x_axis({
        'name': x_label,
        'name_font': {'size': 12},
        'num_font': {'size': 11},
        'label_position': 'low',
        'min': x_min,
        'max': x_max,
        'log_base': x_log_base,
        'num_format': num_format,
        'interval_unit': x_interval_unit,
        'interval_tick': x_interval_tick,
        'visible': x_visible,
    })
    chart.set_y_axis({
        'name': y_label,
        'name_font': {'size': 12},
        'num_font': {'size': 11},
        'label_position': 'low',
        'min': y_min,
        'max': y_max,
        'log_base': y_log_base,
        'num_format': num_format,
        'interval_unit': y_interval_unit,
        'interval_tick': y_interval_tick,
        'visible': y_visible,
    })
    
    # position & size
    if chart_position == 'below':  # anything other than 'below' will put to right
        chart_col = chart_position_state[workbook][chartsheet]['chart_col'] = 1  # reset column
        chart_row = chart_position_state[workbook][chartsheet]['chart_row_below']
    else:
        chart_col = chart_position_state[workbook][chartsheet]['chart_col']
        chart_row = chart_position_state[workbook][chartsheet]['chart_row_right']
        
    chart_worksheet.insert_chart(chart_row, chart_col, chart, {'x_scale': x_scale, 'y_scale': y_scale})

    chart_position_state[workbook][chartsheet]['chart_col'] = chart_col + (8 * x_scale)  # advance column
    chart_position_state[workbook][chartsheet]['chart_row_right'] = chart_row  # save row in case next chart is 'right'
    chart_position_state[workbook][chartsheet]['chart_row_below'] = chart_row + (15 * y_scale)  # advance row in case next chart is 'below'

    return True

# %% [markdown]
# # # Combine and Summarize

# %%
projection_baseline = {  # measured config
    'skx': {'precision': 32},
    'bdx': {'precision': 32},
    'clx': {'precision': 32},
    'amd': {'precision': 0},
}
projection_targets = [  # projected configs
    {'name': 'skx8180 fp32',   'peak gops': 8960,   'peak gbps': 256,  'precision': 32},
    {'name': 'cpx bfloat16',   'peak gops': 50300,  'peak gbps': 614,  'precision': 16},
    {'name': 'cpx int8',       'peak gops': 50300,  'peak gbps': 614,  'precision': 8},
    {'name': 'cpx int4',       'peak gops': 50300,  'peak gbps': 614,  'precision': 4},
    {'name': 'spr-sp int8',    'peak gops': 313098, 'peak gbps': 614,  'precision': 8},
    {'name': 'spr-sp int4',    'peak gops': 313098, 'peak gbps': 614,  'precision': 4},
    {'name': 'spr-ap int8',    'peak gops': 626196, 'peak gbps': 1229, 'precision': 8},
    {'name': 'spr-ap int4',    'peak gops': 626196, 'peak gbps': 1229, 'precision': 4},
]
projection_comparisons = [  # targets to project to
    {'base': 'skx8180 fp32',  'target': 'cpx bfloat16'},
    {'base': 'skx8180 fp32',  'target': 'cpx int8'},
    {'base': 'skx8180 fp32',  'target': 'cpx int4'},
    {'base': 'skx8180 fp32',  'target': 'spr-sp int8'},
    {'base': 'skx8180 fp32',  'target': 'spr-sp int4'},
    {'base': 'skx8180 fp32',  'target': 'spr-ap int8'},
    {'base': 'skx8180 fp32',  'target': 'spr-ap int4'},
    {'base': 'cpx int8',      'target': 'spr-ap int4'},
    {'base': 'spr-sp int8',   'target': 'spr-ap int4'},
]
projection_charts = [  # what to chart across workloads
    {'base': 'skx8180 fp32',  'target': 'cpx int8'},
    {'base': 'skx8180 fp32',  'target': 'spr-sp int8'},
    {'base': 'skx8180 fp32',  'target': 'spr-ap int4'},
    {'base': 'cpx int8',      'target': 'spr-ap int4'},
    {'base': 'spr-sp int8',   'target': 'spr-ap int4'},
]


def get_baseline_precision(row):
    if row['baseline'] in projection_baseline:
        return projection_baseline[row['baseline']]['precision']
    else:
        log("warning", "Can't find baseline precision for %s cpu %s!"%(row['run'], row['cpu_short']))
        return 0

    
def try_avg(x):
    try: 
        return pd.to_numeric(x).mean()
    except Exception:  # else it's a string or object so just take one value
        return x.max()

    
def filter_df(filters, df):
    filter_string = ""
    for column, values in filters.items():
        if column not in df.columns:
            return None
        else:
            if values is None:  # get all of them
                filter_vals = list(df[column].unique())
            elif type(values) is list:  # get list
                filter_vals = values
            else:  # get one value
                filter_vals = [values]

            #coerce column to string for isin() to work
            if column == 'core freq':
                column = 'string core freq'

            if filter_string != "":
                filter_string += " & "
            filter_string += "(df['" + str(column) + "'].isin(" + str(filter_vals) + "))"

    filter_string = "df.loc[" + filter_string + "]"
    return eval(filter_string)


def calc_scaling(workload_df, row, scaling_column):
    if scaling_column not in workload_df.columns:
        log("warning", "%s column not in df"%(scaling_column))
        return None
    
    scaling_vals = list(workload_df[scaling_column].unique())
    if 'default' in scaling_vals:
        scaling_vals.remove('default')
    scaling_vals.sort()
    
    # compare against other scaling vals as baseline
    # return None for lowest val so it's not included in avg scaling because it would be 100%
    scaling_ratio = None
    for scaling_val in scaling_vals:
        baseline = workload_df[workload_df[scaling_column] == scaling_val]['performance'][0]
        if baseline is None or math.isnan(baseline) or \
        row[scaling_column] == 'default' or row[scaling_column] <= scaling_val:
            continue
        
        measured_ratio = float(row['performance']) / float(baseline)
        #if scaling_column == 'string core freq':
        #    ideal_ratio = float(row['metric_CPU operating frequency (in GHz)']) / float(scaling_val)
        #else:
        ideal_ratio = float(row[scaling_column]) / float(scaling_val)
        
        if scaling_ratio is None:
            scaling_ratio = (measured_ratio - 1) / (ideal_ratio - 1)
        else:  # average
            scaling_ratio = (scaling_ratio + ((measured_ratio - 1) / (ideal_ratio - 1))) / 2.0
    
    return scaling_ratio


def calc_pct_change_per_val(workload_df, row, scaling_column, value_column):
    if scaling_column not in workload_df.columns or value_column not in workload_df.columns:
        log("warning", "%s or %s column not in df"%(scaling_column, value_column))
        return None
    
    scaling_vals = list(workload_df[scaling_column].unique())
    if 'default' in scaling_vals:
        scaling_vals.remove('default')
    scaling_vals.sort()
    
    # compare against other scaling vals as baseline
    # return None for lowest val so it's not included in avg scaling because it would be 100%
    avg_pct_change_per_val = None
    for scaling_val in scaling_vals:
        baseline_perf = workload_df[workload_df[scaling_column] == scaling_val]['performance'][0]
        baseline_val = workload_df[workload_df[scaling_column] == scaling_val][value_column][0]
        if baseline_perf is None or math.isnan(baseline_perf) or baseline_val is None or math.isnan(baseline_val) or\
        row[scaling_column] == 'default' or row[scaling_column] <= scaling_val:
            continue
        
        pct_change = (float(row['performance']) - float(baseline_perf)) / float(baseline_perf)
        val_diff = (float(baseline_val) - float(row[value_column]))
        pct_change_per_val = pct_change / val_diff
        
        if avg_pct_change_per_val is None:
            avg_pct_change_per_val = pct_change_per_val
        else:  # average
            avg_pct_change_per_val = (avg_pct_change_per_val + pct_change_per_val) / 2.0
        
    if avg_pct_change_per_val is not None:
        avg_pct_change_per_val *= 100
        
    return avg_pct_change_per_val


def create_filter_summary(workloads):
    print("Creating Filter Summary...")
    desired_columns = ['run', 'interval', 'INST_RETIRED.ANY', 'metric_GFLOPS/s', 'suggested_start', 'suggested_stop']
    filter_summary = pd.DataFrame(columns=desired_columns)
    filter_summary_file = results_dir + "/filter_summary.xlsx" 
    for entry in workloads:
        run = entry['name']
        dir = entry['emon_dir']
        metrics = entry['metrics']
        new_granularity_sec = entry['agg_secs']
        file = dir + "/%s_emon_%.3fsec_metrics.csv"%(run, new_granularity_sec)
        
        if os.path.isfile(file):
            whole_workload = pd.read_csv(file, index_col=0)
            filter_summary = filter_summary.append(whole_workload[desired_columns] , ignore_index=True)
            log("info", "%s has %d rows"%(run, len(whole_workload)))
        else:
            log("warning", "Can't find %s to create filter summary"%(file))
            continue
            
    # create filter summary (allows human validation for start/stop times)
    log("info", "Generating filter Excel...")
    writer = pd.ExcelWriter(filter_summary_file, engine='xlsxwriter')
    workbook = writer.book
    
    start_row = end_row = 0
    sheet_row_count = next_sheet_row_count = 0
    sheet_count = 0
    current_sheet = 'Data' + str(sheet_count)
    sheet_legend = {}
    for entry in workloads:
        if entry['name'] not in list(filter_summary['run'].unique()) or \
        len(filter_summary.index[filter_summary['run'] == entry['name']].tolist()) <= 1:
            continue
            
        first_row = filter_summary.index[filter_summary['run'] == entry['name']].tolist()[0]
        last_row = filter_summary.index[filter_summary['run'] == entry['name']].tolist()[-1]
        wl_rows = last_row - first_row + 1
        next_sheet_row_count += wl_rows
        
        if wl_rows >= 1e6:  # unlikely, but possible
            log("error", "%s has %d rows => too many rows!!!"%(entry['name'], wl_rows))
            
        if next_sheet_row_count > 1e6:  # separate every million rows to new sheet
            end_row += sheet_row_count
            log("info", "Saving df rows %d : %d to %s"%(start_row, end_row, current_sheet))
            filter_summary.iloc[start_row:end_row].to_excel(writer, sheet_name=current_sheet)
            sheet_row_count = 0
            next_sheet_row_count = last_row - first_row + 1
            start_row = end_row
            sheet_count += 1
            current_sheet = 'Data' + str(sheet_count)
            
        sheet_legend[entry['name']] = {'sheet': current_sheet, 'start': sheet_row_count+1, 'stop': next_sheet_row_count}
        sheet_row_count = next_sheet_row_count
    
    end_row += sheet_row_count
    log("info", "Saving df rows %d : %d to %s"%(start_row, end_row, current_sheet))
    filter_summary.iloc[start_row:end_row].to_excel(writer, sheet_name=current_sheet)

    # create charts
    log("info", "Creating filter charts...")
    workbook.add_worksheet('Charts')
    for entry in workloads:
        if entry['name'] not in sheet_legend:
            continue
            
        df = filter_summary[filter_summary['run'] == entry['name']]
        add_chart(
            workbook=workbook,
            chartsheet='Charts',
            datasheet=sheet_legend[entry['name']]['sheet'],
            df=filter_summary,
            chart_type='scatter',
            chart_subtype='smooth',
            start_row=sheet_legend[entry['name']]['start'],
            end_row=sheet_legend[entry['name']]['stop'],
            x_col_name='interval',
            y_col_names=['INST_RETIRED.ANY'],
            series_names=['Instructions Retired'],
            title=entry['name'],
            x_label='Interval',
            y_label='Instructions Retired',
            y_min=0,
            additional_series=[
                {
                    'name':       'Start',
                    'categories': [df.iloc[df['suggested_start'].values[0]]['interval'], df.iloc[df['suggested_start'].values[0]]['interval']],
                    'values':     [0, df['INST_RETIRED.ANY'].max()],
                    'line':       {'color': 'green'},
                    'marker':     {'type': 'none'},
                },
                {
                    'name':       'Stop',
                    'categories': [df.iloc[df['suggested_stop'].values[0]]['interval'], df.iloc[df['suggested_stop'].values[0]]['interval']],
                    'values':     [0, df['INST_RETIRED.ANY'].max()],
                    'line':       {'color': 'red'},
                    'marker':     {'type': 'none'},
                },
            ]
        )
        add_chart(
            workbook=workbook,
            chartsheet='Charts',
            datasheet=sheet_legend[entry['name']]['sheet'],
            df=filter_summary,
            chart_type='scatter',
            chart_subtype='smooth',
            start_row=sheet_legend[entry['name']]['start'],
            end_row=sheet_legend[entry['name']]['stop'],
            x_col_name='interval',
            y_col_names=['metric_GFLOPS/s'],
            series_names=['GFLOPS/s'],
            title=entry['name'],
            x_label='Interval',
            y_label='GFLOPS/s',
            y_min=0,
            chart_position='right',
            additional_series=[
                {
                    'name':       'Start',
                    'categories': [df.iloc[df['suggested_start'].values[0]]['interval'], df.iloc[df['suggested_start'].values[0]]['interval']],
                    'values':     [0, df['metric_GFLOPS/s'].max()],
                    'line':       {'color': 'green'},
                    'marker':     {'type': 'none'},
                },
                {
                    'name':       'Stop',
                    'categories': [df.iloc[df['suggested_stop'].values[0]]['interval'], df.iloc[df['suggested_stop'].values[0]]['interval']],
                    'values':     [0, df['metric_GFLOPS/s'].max()],
                    'line':       {'color': 'red'},
                    'marker':     {'type': 'none'},
                },
            ]
        )
    writer.save()
    
    
def combine_and_summarize(workloads):
    log("info", "Combining and averaging EMON...")
    start_time = time.time()
    
    # create dirs if necessary
    if os.path.isdir(results_dir) != True:
        subprocess.check_output("mkdir %s"%(results_dir), shell=True)
    flops_dir = results_dir + "/flops"
    if os.path.isdir(flops_dir) != True:
        subprocess.check_output("mkdir %s"%(flops_dir), shell=True)
    default_dir = results_dir + "/default"
    if os.path.isdir(default_dir) != True:
        subprocess.check_output("mkdir %s"%(default_dir), shell=True)
    memory_dir = results_dir + "/memory"
    if os.path.isdir(memory_dir) != True:
        subprocess.check_output("mkdir %s"%(memory_dir), shell=True)
    
    flops_summary_file = results_dir + "/flops_emon_metrics_avg.xlsx"
    default_summary_file = results_dir + "/default_emon_metrics_avg.xlsx"
    memory_summary_file = results_dir + "/memory_emon_metrics_avg.xlsx"
    
    # read in existing files
    if os.path.exists(flops_summary_file):
        flops_summary = pd.read_excel(flops_summary_file, index_col=0, sheet_name='EMON', header=0)
    else:
        flops_summary = pd.DataFrame()
        
    if os.path.exists(default_summary_file):
        default_summary = pd.read_excel(default_summary_file, index_col=0, sheet_name='EMON', header=0)
    else:
        default_summary = pd.DataFrame()
        
    if os.path.exists(memory_summary_file):
        memory_summary = pd.read_excel(memory_summary_file, index_col=0, sheet_name='EMON', header=0)
    else:
        memory_summary = pd.DataFrame()
    
    # filter and average each workload, add to summary
    for entry in workloads:
        run = entry['name']
        #print("\t%s..."%(run))
        dir = entry['emon_dir']
        metrics = entry['metrics']
        new_granularity_sec = entry['agg_secs']
        file = dir + "/%s_emon_%.3fsec_metrics.csv"%(run, new_granularity_sec)
        excel_file = dir + "/%s_emon_%.3fsec_metrics.xlsx"%(run, new_granularity_sec)
        
        if os.path.isfile(file):
            whole_workload = pd.read_csv(file, index_col=0)
        else:
            log("warning", "Can't find %s to summarize"%(file))
            continue
        
        # filter start/stop time
        suggested_start = whole_workload['suggested_start'].values[0]
        suggested_stop = whole_workload['suggested_stop'].values[0]
        filtered_workload = whole_workload.loc[suggested_start:suggested_stop]
    
        try:
            avg_df = filtered_workload.apply(lambda x: try_avg(x), axis=0)  # convert columns to numeric & avg
            avg_df['last_updated'] = str(datetime.now())
            avg_df = avg_df.rename(run)
            
            # add to summary
            if '2s.xml' in metrics or 'proxy-only.xml':
                if 'run' in default_summary and run in default_summary['run'].values:  # drop if exists
                    default_summary = default_summary.drop(default_summary[default_summary['run'] == run].index)
                default_summary = default_summary.append(avg_df)  # add it
                if os.path.isfile(excel_file):
                    subprocess.check_output("cp %s %s"%(excel_file, default_dir), shell=True)
            elif 'flops-only.xml' in metrics:
                if 'run' in flops_summary and run in flops_summary['run'].values:  # drop if exists
                    flops_summary = flops_summary.drop(flops_summary[flops_summary['run'] == run].index)
                flops_summary = flops_summary.append(avg_df)  # add it
                if os.path.isfile(excel_file):
                    subprocess.check_output("cp %s %s"%(excel_file, flops_dir), shell=True)
            elif 'memory-only.xml' in metrics:
                if 'run' in memory_summary and run in memory_summary['run'].values:  # drop if exists
                    memory_summary = memory_summary.drop(memory_summary[memory_summary['run'] == run].index)
                memory_summary = memory_summary.append(avg_df)  # add it
                if os.path.isfile(excel_file):
                    subprocess.check_output("cp %s %s"%(excel_file, memory_dir), shell=True)
            else:  # put it in default
                default_summary = default_summary.append(avg_df)  # add it
                if os.path.isfile(excel_file):
                    subprocess.check_output("cp %s %s"%(excel_file, default_dir), shell=True)
        except Exception as e:
            log("error", "Exception %s: %s"%(sys.exc_info()[0], e)) 
        
    #create xlsx writer and save EMON data
    for file, df in [
        (flops_summary_file, flops_summary),
        (memory_summary_file, memory_summary),
        (default_summary_file, default_summary),
    ]:
        
    #for file, df in [(default_summary_file, default_summary)]:
        log("info", "Processing %s..."%(file))
        if not df.empty:
            # average across runs for each workload
            if 'run_count' in df:
                #df['unique_workload_name'] = df.apply(lambda x: x['workload'].replace(x['run_count'],'').rstrip('-'), axis=1)
                df['workload_index'] = df.apply(lambda x: x['workload'].replace(x['run_count'],'').rstrip('-'), axis=1)
                df = df.groupby('workload_index').agg(try_avg)  # groupby runs, and average
            
            df = df.sort_index()  # sort by workload name so they are grouped together
            df['row'] = list(range(len(df.index)))  # because index is not a number
            best_df = pd.DataFrame(columns=df.columns)
            workload_best_configs = {}  # store highest config for each workload
            workload_all_configs = {}  # store all configs for each workload
            # calculate scaling efficiencies
            df['string core freq'] = df['core freq'].apply(lambda x: format_core_freq(x)) # workaround because original core freq column is mixed datatype
            log("info", "Calculating workload scaling...")
            for workload in list(df['workload'].unique()):
                all_core_freq = list(df[df['workload'] == workload]['string core freq'].unique())
                all_core_freq.sort()
                best_core_freq = all_core_freq[-2] if all_core_freq[-1] == 'default' and len(all_core_freq) > 1 else all_core_freq[-1]
                all_core_count = list(df[df['workload'] == workload]['cores used'].unique())
                all_core_count.sort()
                best_core_count = int(all_core_count[-2] if all_core_count[-1] == 'default' and len(all_core_count) > 1 else all_core_count[-1])
                all_dram_freq = list(df[df['workload'] == workload]['DRAM freq'].unique())
                all_dram_freq.sort()
                best_dram_freq = int(all_dram_freq[-2] if all_dram_freq[-1] == 'default' and len(all_dram_freq) > 1 else all_dram_freq[-1])
                workload_best_configs[workload] = {'core freq': best_core_freq, 'DRAM freq': best_dram_freq, 'cores used': best_core_count}
                workload_all_configs[workload] = {'core freq': all_core_freq, 'DRAM freq': all_dram_freq, 'cores used': all_core_count}
                
                workload_df = filter_df({'workload': workload, 'DRAM freq': best_dram_freq, 'cores used': best_core_count}, df)
                df.loc[df['workload'] == workload, 'core freq scaling'] = df[(df['workload'] == workload) & (df['DRAM freq'] == best_dram_freq) & (df['cores used'] == best_core_count)].apply(lambda row: calc_scaling(workload_df, row, 'string core freq'), axis=1)
                # core count per run
                workload_df = filter_df({'workload': workload, 'DRAM freq': best_dram_freq, 'core freq': best_core_freq}, df)
                df.loc[df['workload'] == workload, 'core count scaling'] = df[(df['workload'] == workload) & (df['DRAM freq'] == best_dram_freq) & (df['string core freq'] == best_core_freq)].apply(lambda row: calc_scaling(workload_df, row, 'cores used'), axis=1)
                # DRAM freq per run
                workload_df = filter_df({'workload': workload, 'cores used': best_core_count, 'core freq': best_core_freq}, df)
                df.loc[df['workload'] == workload, 'DRAM freq scaling'] = df[(df['workload'] == workload) & (df['string core freq'] == best_core_freq) & (df['cores used'] == best_core_count)].apply(lambda row: calc_scaling(workload_df, row, 'DRAM freq'), axis=1)
                df.loc[df['workload'] == workload, '% perf change / DRAM ns'] = df[(df['workload'] == workload) & (df['string core freq'] == best_core_freq) & (df['cores used'] == best_core_count)].apply(lambda row: calc_pct_change_per_val(workload_df, row, 'DRAM freq', 'metric_Average LLC data read (demand+prefetch) miss latency (in ns)'), axis=1)
                # calc efficiency as average of appropriate runs
                df.loc[df['workload'] == workload, 'core freq efficiency'] = df[df['workload'] == workload]['core freq scaling'].mean()
                df.loc[df['workload'] == workload, 'core count efficiency'] = df[df['workload'] == workload]['core count scaling'].mean()
                df.loc[df['workload'] == workload, 'DRAM freq efficiency'] = df[df['workload'] == workload]['DRAM freq scaling'].mean()
                df.loc[df['workload'] == workload, 'workload % perf change / DRAM ns'] = df[df['workload'] == workload]['% perf change / DRAM ns'].mean()
            
                # create subset df of just best configs for each workload
                best_df = best_df.append(filter_df({'workload': workload, 'core freq': best_core_freq, 'DRAM freq': best_dram_freq, 'cores used': best_core_count}, df), sort=False)
            
            projection_df = None
            if 'metric_FLOPS' in df:
                # create roofline flops projections data
                log("info", "Calculating FLOPS Projections...")
                projection_df = best_df[['run', 'duration','metric_FLOPS', 'DRAM Bytes', 'Theoretical Peak DRAM GB/s', 'Theoretical Peak GFLOPS/s', 'Roofline Elbow']].copy()
                #re-calculate baseline metrics because they average differently and add error to projections
                projection_df['metric_GFLOPS/s'] = projection_df['metric_FLOPS'] / projection_df['duration'] / 1e9
                projection_df['metric_Arithmetic Intensity'] = projection_df['metric_FLOPS'] / projection_df['DRAM Bytes']
                projection_df['baseline boundedness'] = projection_df.apply(lambda row: 'memory' if row['metric_Arithmetic Intensity'] < row['Roofline Elbow'] else 'compute', axis=1)
                projection_df['Achievable Peak GFLOPS/s'] = projection_df.apply(lambda row: min(row['Theoretical Peak GFLOPS/s'], row['Theoretical Peak DRAM GB/s'] * row['metric_Arithmetic Intensity']), axis=1)
                projection_df['FP Efficiency %'] = projection_df['metric_GFLOPS/s'] / projection_df['Achievable Peak GFLOPS/s'] * 100.0
                projection_df['baseline'] = best_df['cpu_short']
                for target in projection_targets:
                    projection_df[target['name'] + ' AI'] = projection_df.apply(lambda row: (get_baseline_precision(row) / target['precision']) * row['metric_Arithmetic Intensity'], axis=1)
                    projection_df[target['name'] + ' Achievable GOPS'] = projection_df.apply(lambda row: min(target['peak gops'], row[target['name'] + ' AI'] * target['peak gbps']), axis=1)
                    projection_df[target['name'] + ' Realistic GOPS'] = projection_df[target['name'] + ' Achievable GOPS'] * (projection_df['FP Efficiency %'] / 100)
                    projection_df['baseline to ' + target['name']] = projection_df[target['name'] + ' Realistic GOPS'] / projection_df['metric_GFLOPS/s']
                for comparison in projection_comparisons:
                    projection_df[comparison['base'] + ' to ' + comparison['target']] = projection_df[comparison['target'] + ' Realistic GOPS'] / projection_df[comparison['base'] + ' Realistic GOPS']
            
            # create chart writer
            log("info", "Creating Charts...")
            writer = pd.ExcelWriter(file, engine='xlsxwriter')
            workbook = writer.book
            df.to_excel(writer, sheet_name='EMON')
            best_df.to_excel(writer, sheet_name='Best Config')
            
            #create bounding box summary tab
            if set(bb_columns).issubset(df.columns):
                bb_df = best_df[bb_columns].copy()
                bb_df = bb_df.transpose()
                bb_df.to_excel(writer, sheet_name='Bounding Box')
                
            # create proxy metrics summary tab
            proxy_cols = proxy_columns + ['core freq efficiency', 'core count efficiency', 'DRAM freq efficiency', 'workload % perf change / DRAM ns']
            proxy_names = proxy_rename + ['Core Freq Eff', 'Core Count Eff', 'DRAM Freq Eff', 'perf % / DRAM ns']
            if not set(proxy_cols).issubset(df.columns):
                for column in proxy_cols:
                    if column not in best_df:
                        best_df[column] = None
            proxy_df = best_df[proxy_cols].copy()
            proxy_df.columns = proxy_names
            proxy_df = proxy_df.transpose()
            proxy_df.to_excel(writer, sheet_name='Proxy Metrics')
            
            # create flops projection summary tab
            if projection_df is not None:
                projection_df.to_excel(writer, sheet_name='FLOPS Projection')
                projection_series = []
                for comparison in projection_charts:
                    projection_series.append(comparison['base'] + ' to ' + comparison['target'])

            # create chart(s)
            start_row = 1
            end_row = len(df.index)
            workbook.add_worksheet('Charts')
            
            if projection_df is not None:
                add_chart(
                    workbook=workbook,
                    chartsheet='FLOPS Projection',
                    datasheet='FLOPS Projection',
                    df=projection_df,
                    chart_type='bar',
                    start_row=1,
                    end_row=len(projection_df.index),
                    x_col_name='run',
                    y_col_names=projection_series,
                    title='FLOPS Projection',
                    x_label='Perf Change',  # bar charts have x & y axis reversed
                    y_interval_unit=1,  # bar charts have x & y axis reversed
                    x_log_base=10, # bar charts have x & y axis reversed
                    y_scale=6,
                    x_scale=3,
                )
            add_chart(
                workbook=workbook,
                chartsheet='Charts',
                datasheet='EMON',
                df=df,
                chart_type='bar',
                chart_subtype='stacked',
                start_row=start_row,
                end_row=end_row,
                x_col_name='run',
                y_col_names=[
                    'metric_TMAM_Retiring(%)',
                    'metric_TMAM_Frontend_Bound(%)',
                    'metric_TMAM_Backend_bound(%)',
                    'metric_TMAM_Bad_Speculation(%)',
                ],
                series_names=['Retiring %', 'Frontend Bound %', 'Backend Bound %', 'Bad Speculation %'],
                title='TMAM Level 1',
                x_label='% Cycles Spent', # bar charts have x & y axis reversed
                y_interval_unit=1,  # bar charts have x & y axis reversed
                gap=50,
                x_min=0,
                x_max=100,  # bar charts have x & y axis reversed
                y_scale=4,
                x_scale=3,
            )
            add_chart(
                workbook=workbook,
                chartsheet='Charts',
                datasheet='EMON',
                df=df,
                chart_type='bar',
                chart_subtype='stacked',
                start_row=start_row,
                end_row=end_row,
                x_col_name='run',
                y_col_names=[
                    'metric_TMAM_..Base(%)',
                    'metric_TMAM_..Microcode_Sequencer(%)',
                    'metric_TMAM_..Branch_Mispredicts(%)',
                    'metric_TMAM_..Machine_Clears(%)',
                    'metric_TMAM_..Frontend_Latency(%)',
                    'metric_TMAM_..Frontend_Bandwidth(%)',
                    'metric_TMAM_..Core_Bound(%)',
                    'metric_TMAM_..Memory_Bound(%)',
                ],
                series_names=['Retiring:Base', 'Retiring:MS-ROM', 'Bad Spec:Branch Mispredict',
                              'Bad Spec:Machine Clears', 'Frontend:Latency', 'Frontend:Bandwidth', 'Backend:Core',
                             'Backend:Memory'],
                title='TMAM Level 2',
                x_label='% Cycles Spent', # bar charts have x & y axis reversed
                y_interval_unit=1,  # bar charts have x & y axis reversed
                gap=50,
                x_min=0,
                x_max=100,  # bar charts have x & y axis reversed
                y_scale=4,
                x_scale=3,
            )
            add_chart(
                workbook=workbook,
                chartsheet='Charts',
                datasheet='EMON',
                df=best_df,
                start_row=start_row,
                end_row=end_row,
                chart_type='column',
                x_col_name='workload',
                y_col_names=['core freq efficiency', 'core count efficiency', 'DRAM freq efficiency'],
                series_filters={  # will get all workloads with more than one config and use 'row' value of best_df to plot from regular df
                    'workload': [workload for workload in df['workload'].unique() if \
                                 len(workload_all_configs[workload]['DRAM freq']) > 1 or \
                                 len(workload_all_configs[workload]['core freq']) > 1 or \
                                 len(workload_all_configs[workload]['cores used']) > 1]
                },
                title= 'Scaling Efficiency',
            )
            
            for workload in list(df['workload'].unique()):
                next_position = 'below'
                if len(workload_all_configs[workload]['core freq']) > 1:
                    add_chart(
                        workbook=workbook,
                        chartsheet='Charts',
                        datasheet='EMON',
                        df=df,
                        start_row=None,
                        end_row=None,
                        chart_type='scatter',
                        x_col_name='metric_CPU operating frequency (in GHz)',
                        y_col_names=['performance'],
                        series_filters={'workload': workload, 'DRAM freq': workload_best_configs[workload]['DRAM freq'], 'cores used': workload_best_configs[workload]['cores used']},
                        title= workload + ' Core Frequency Scaling',
                        x_label='Core Frequency (GHz)',
                        y_label='Performance',
                        disable_legend=True,
                        chart_position=next_position,
                        trendline={'type': 'power', 'display_equation': True, 'display_r_squared': True},
                    )
                    next_position = 'right'
                if len(workload_all_configs[workload]['cores used']) > 1:
                    add_chart(
                        workbook=workbook,
                        chartsheet='Charts',
                        datasheet='EMON',
                        df=df,
                        start_row=None,
                        end_row=None,
                        chart_type='scatter',
                        x_col_name='cores used',
                        y_col_names=['performance'],
                        series_filters={'workload': workload, 'string core freq': workload_best_configs[workload]['core freq'], 'DRAM freq': workload_best_configs[workload]['DRAM freq']},
                        title= workload + ' Core Count Scaling',
                        x_label='Cores',
                        y_label='Performance',
                        disable_legend=True,
                        chart_position=next_position,
                        trendline={'type': 'power', 'display_equation': True, 'display_r_squared': True},
                    )
                    next_position = 'right'
                if len(workload_all_configs[workload]['DRAM freq']) > 1:
                    add_chart(
                        workbook=workbook,
                        chartsheet='Charts',
                        datasheet='EMON',
                        df=df,
                        start_row=None,
                        end_row=None,
                        chart_type='scatter',
                        x_col_name='DRAM freq',
                        y_col_names=['performance'],
                        series_filters={'workload': workload, 'string core freq': workload_best_configs[workload]['core freq'], 'cores used': workload_best_configs[workload]['cores used']},
                        title= workload + ' DRAM Frequency Scaling',
                        x_label='DRAM Frequency (MHz)',
                        y_label='Performance',
                        disable_legend=True,
                        chart_position=next_position,
                        trendline={'type': 'power', 'display_equation': True, 'display_r_squared': True},
                    )
                    next_position = 'right'
                    add_chart(
                        workbook=workbook,
                        chartsheet='Charts',
                        datasheet='EMON',
                        df=df,
                        start_row=None,
                        end_row=None,
                        chart_type='scatter',
                        x_col_name='metric_Average LLC data read (demand+prefetch) miss latency (in ns)',
                        y_col_names=['performance'],
                        series_filters={'workload': workload, 'string core freq': workload_best_configs[workload]['core freq'], 'cores used': workload_best_configs[workload]['cores used']},
                        title= workload + ' DRAM Latency Scaling',
                        x_label='DRAM Read Latency (ns)',
                        y_label='Performance',
                        disable_legend=True,
                        chart_position=next_position,
                        trendline={'type': 'power', 'display_equation': True, 'display_r_squared': True},
                    )
                    add_chart(
                        workbook=workbook,
                        chartsheet='Charts',
                        datasheet='EMON',
                        df=df,
                        start_row=None,
                        end_row=None,
                        chart_type='scatter',
                        x_col_name='DRAM freq',
                        y_col_names=['metric_Average LLC data read (demand+prefetch) miss latency (in ns)'],
                        series_filters={'workload': workload, 'string core freq': workload_best_configs[workload]['core freq'], 'cores used': workload_best_configs[workload]['cores used']},
                        title= workload + ' DRAM Latency',
                        x_label='DRAM Frequency (MHz)',
                        y_label='DRAM Read Latency (ns)',
                        disable_legend=True,
                        chart_position=next_position,
                        trendline={'type': 'power', 'display_equation': True, 'display_r_squared': True},
                    )
                    
                
            
            #write to file
            writer.save()
        
    log("info", "Finished in %d secs\n"%(time.time() - start_time))

# %% [markdown]
# # # MAIN

# %%
def process_workload(entry):
    try:
        convert_to_csv(entry)
    except Exception as e:
        log("error", "Error converting %s to csv! %s: %s"%(entry['name'], sys.exc_info()[0], e))
    
    try:
        aggregate(entry)
    except Exception as e:
        log("error", "Error aggregating %s! %s: %s"%(entry['name'], sys.exc_info()[0], e))
    
    try:
        calculate_metrics(entry)
    except Exception as e:
        log("error", "Error calculating metrics for %s! %s: %s"%(entry['name'], sys.exc_info()[0], e))
    
    try:
        create_excel(entry)
    except Exception as e:
        log("error", "Error creating excel for %s! %s: %s"%(entry['name'], sys.exc_info()[0], e))

# %%
absolute_start = time.time()
GENERATE_PER_CORE = False  # will additionally generate raw per-core csv (no aggregation)
DEBUG = False  # turns on some debug print statements, mostly for calculate_metrics
OVERWRITE = True  # overwrite existing results if true, skip if false
DRY_RUN = False  # set true to just create workload list but not process anything
SUMMARIZE_ONLY = False  # don't create csv/aggregate/etc, just re-create summary

# set which workloads to process / combine
# list type will search through dir path, workloads is straight list of EMON
#workload_lists = [aibench_collection_5_10, cwr]
workload_lists = [aibt_121619]
#workloads = aibt_clx_2933

if 'workloads' not in locals() and 'workload_lists' in locals():
    workloads = []
    print("Creating workload list...")
    for workload_list in workload_lists:
        temp_list = create_workload_list(workload_list)
        workloads += temp_list
    list_time = time.time()
    log("info", "Found %d workloads in %d secs\n"%(len(workloads), list_time - absolute_start))

    # don't process flops results
    #temp_workloads = []
    #for idx, workload in enumerate(workloads):
    #    if 'Flops' not in workload['name']:
    #        temp_workloads.append(workload)
    #workloads = temp_workloads

#workloads += aibt_clx_2933

temp_workloads = copy.deepcopy(workloads)
workloads_to_remove = [ 
    'draw-eigen-float32',
    'draw-mkldnn-float32',
    'inception-resnet-v2-eigen-float32',
    'inception-resnet-v2-eigen-int8',
    'inception-resnet-v2-mkldnn-float32',
    'inception-resnet-v2-mkldnn-int8',
    'mobilenet-v1-eigen-float32',
    'mobilenet-v1-mkldnn-float32',
    'unet-eigen-float32',
    'unet-mkldnn-float32',
    'wide-and-deep-eigen-int8',
    'wide-and-deep-mkldnn-int8',
]
for workload in temp_workloads:
    for name in workloads_to_remove:
        if name in workload['name']:
            print("Removing %s from workload list"%(workload['name']))
            workloads.remove(workload)

#temp_workloads = copy.deepcopy(workloads)
#for workload in temp_workloads:
#    if 'resnet-50-v1' not in workload['name']:
#        workloads.remove(workload)
            
if len(workloads) >= 1 and DRY_RUN == False:
    if SUMMARIZE_ONLY == False:
        pool = Pool()
        pool.map(process_workload, workloads)
        pool.close()

        if 'results_dir' in workloads[0]:
            results_dir = workloads[0]['results_dir']
        else:
            results_dir = "/mnt/san03RAID1/users/mablackm/aibench_emon/results/" + datetime.now().strftime("%Y-%m-%d_%H:%M")

    combine_and_summarize(workloads)
    #create_filter_summary(workloads)
else:
    log("warning", "No workloads were processed...")


log("info", "Completed %d workloads in %d sec\n"%(len(workloads), time.time() - absolute_start))

print("\n\nSummary of Warnings (%d):"%(len(warnings)))
for num, item in enumerate(warnings):
    print("[%d]\t%s"%(num, item)) 
print("\n\nSummary of Errors (%d):"%(len(errors)))
for num, item in enumerate(errors):
    print("[%d]\t%s"%(num, item)) 
    
del workloads
# Out:
# Creating workload list...
# [INFO][186303]	 Found 156 workloads in 0 secs
#
# Removing unet-eigen-float32-Run1_56i_1cpi_defcf_defuf_2933df_default from workload list
# Removing unet-mkldnn-float32-Run3_56i_1cpi_defcf_defuf_2933df_default from workload list
# Removing unet-eigen-float32-Run2_56i_1cpi_defcf_defuf_2933df_default from workload list
# Removing unet-mkldnn-float32-Run2_56i_1cpi_defcf_defuf_2933df_default from workload list
# Removing unet-eigen-float32-Run3_56i_1cpi_defcf_defuf_2933df_default from workload list
# Removing unet-mkldnn-float32-Run1_56i_1cpi_defcf_defuf_2933df_default from workload list
# Removing wide-and-deep-eigen-int8-Run3_56i_1cpi_defcf_defuf_2933df_default from workload list
# Removing wide-and-deep-eigen-int8-Run2_56i_1cpi_defcf_defuf_2933df_default from workload list
# Removing wide-and-deep-mkldnn-int8-Run2_56i_1cpi_defcf_defuf_2933df_default from workload list
# ...
